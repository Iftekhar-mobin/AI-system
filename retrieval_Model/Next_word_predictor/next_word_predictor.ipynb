# %%
import re
import ast
from os import path
from nltk import bigrams, trigrams
from collections import Counter, defaultdict
from nltk.util import ngrams

# %%
def trigram_model(data, model):
    for sentence in data:
        for w1, w2, w3 in trigrams(sentence.split(), pad_right=True, pad_left=True):
            model[(w1, w2)][w3] += 1
    return model

# %%
# Create a placeholder for model
model = defaultdict(lambda: defaultdict(lambda: 0))

# %%
directory = '/home/iftekhar/amiebot/Resources/876/data/'
file = open(path.join(directory, "tokenized_dict.json"), "r")
contents = file.read()
features_dict = ast.literal_eval(contents)
file.close()

# %%
for records in features_dict.values():
    for lines in records:
        if lines:
            lines = re.sub('\s+',' ', lines).strip()
            for w1, w2, w3 in trigrams(lines.split(), pad_right=True, pad_left=True):
                model[(w1, w2)][w3] += 1
#             for w1, w2, w3, w4 in list(ngrams(lines.split(), n=4)):
#                 model[(w1, w2, w3)][w4] += 1

# %%
model

# %%
from pathlib import Path

def load_corpus(corpus_name):
    data_file = Path(corpus_name)
    with open(data_file, encoding='utf-8') as f:
        data_list = f.read().splitlines()
    return data_list

# %%
data = load_corpus('/home/iftekhar/amiebot/amieCore/amie_core/apis/corpus_dashboard/processed_texts.txt')

# %%
# Count frequency of co-occurance  
for sentence in data:
    for w1, w2, w3 in trigrams(sentence.split(), pad_right=True, pad_left=True):
        model[(w1, w2)][w3] += 1

# %%
# Count frequency of co-occurance  
for sentence in data:
    sent = sentence.split()
    for w1, w2, w3, w4 in list(ngrams(sent, n=4)):
        model[(w1, w2, w3)][w4] += 1

# %%
# Count frequency of co-occurance  
for sentence in data:
    sent = sentence.split()
    for w1, w2, w3, w4 in list(ngrams(sent, n=4)):
        print(w1,"-", w2, "-", w3, "-", w4)
    break
        #model[(w1, w2, w3)][w4] += 1

# %%
for w1_w2 in model:
#     if w1_w2[0]:
#         print(w1_w2)
#         break
    total_count = float(sum(model[w1_w2].values()))
    for w3 in model[w1_w2]:
        model[w1_w2][w3] /= total_count

# %%
model

# %%
for w2_w3 in model:
    total_count = float(sum(model[w2_w3].values()))
    for w4 in model[w2_w3]:
        model[w2_w3][w4] /= total_count

# %%
sorted(dict(model['地理的', '位置', '履歴']), reverse=True)
# Out:
# ['表示']

# %%
dict(model['地理的', '位置'])
# Out:
# {'表示': 0.42000000000000004,
#  '送る': 0.04,
#  '履歴': 0.02,
#  'コンソール': 0.049999999999999996,
#  '監視': 0.01,
#  'エラーログ': 0.02,
#  '収集': 0.030000000000000002,
#  'インストール': 0.01,
#  'PC': 0.02,
#  'その': 0.030000000000000002,
#  'メモリ容量': 0.02,
#  'バッテリ': 0.04,
#  '把握': 0.060000000000000005,
#  '地図': 0.030000000000000002,
#  '情報': 0.02,
#  'どの': 0.02,
#  '拡大': 0.08,
#  '追跡': 0.02,
#  '起動': 0.01,
#  '変化': 0.01,
#  '知る': 0.02,
#  '取得': 0.02}

# %%
import random

# starting words
text = ["Android", "Plus"]
# text = ['地理的', '位置']


#random.seed(1)

collector = []
i=10
while i > 0:
    sentence_finished = False
    #r = random.uniform(0.5, 1.0)
    while not sentence_finished:
      # select a random probability threshold  
      
      accumulator = .0

      for word in model[tuple(text[-2:])].keys():
          accumulator += model[tuple(text[-2:])][word]
          # select words that are above the probability threshold
          
          if accumulator >= random.random():
              #print(r)
              text.append(word)
              break

      if text[-2:] == [None, None]:
          sentence_finished = True

    result = ' '.join([t for t in text if t])
    collector.append(result)
    i -= 1
    
#result
# for x in [t for t in text if t]:
#     print(x)

# %%
list(set(collector))
# Out:
# ['Android Plus Android Enterprise プラグイン 提供 いる Android標準ブラウザ 利用 SOTI Surf ダウンロード ファイル 開く ます 端末 グループ 作る おく ます 会社 認める アプリ 開く 端末 初期 セットアップ ます',
#  'Android Plus Android Enterprise プラグイン 提供 いる Android標準ブラウザ 利用 SOTI Surf ダウンロード ファイル 開く ます 端末 グループ 作る おく ます 会社 認める アプリ 開く 端末 初期 セットアップ ます 但し MobiControl サーバ チェックイン 最新 正常 性 構成 証明書 不 正常 エンド ポイント PC 特別 端末 グループ 作る 端末 所属 端末 グループ 作成 ます 構成 プロファイル 手動 インストール ない プロファイル ボタン 押す エージェント チェックイン 時刻 登録 実行 ます ルール macOS コンピュータ macOS',
#  'Android Plus Android Enterprise プラグイン 提供 いる Android標準ブラウザ 利用 SOTI Surf ダウンロード ファイル 開く ます 端末 グループ 作る おく ます 会社 認める アプリ 開く 端末 初期 セットアップ ます 但し MobiControl サーバ チェックイン 最新 正常 性 構成 証明書 不 正常 エンド ポイント PC 特別 端末 グループ 作る 端末 所属 端末 グループ 作成 ます 構成 プロファイル 手動 インストール ない プロファイル ボタン 押す エージェント チェックイン 時刻 登録 実行 ます',
#  'Android Plus Android Enterprise プラグイン 提供 いる Android標準ブラウザ 利用 SOTI Surf ダウンロード ファイル 開く ます 端末 グループ 作る おく ます 会社 認める アプリ 開く 端末 初期 セットアップ ます 但し MobiControl サーバ チェックイン 最新 正常 性 構成 証明書 不 正常 エンド ポイント PC 特別 端末 グループ 作る 端末 所属 端末 グループ 作成 ます 構成 プロファイル 手動 インストール ない プロファイル ボタン 押す',
#  'Android Plus Android Enterprise プラグイン 提供 いる Android標準ブラウザ 利用 SOTI Surf ダウンロード ファイル 開く ます 端末 グループ 作る おく ます 会社 認める アプリ 開く',
#  'Android Plus Android Enterprise プラグイン 提供 いる Android標準ブラウザ 利用 SOTI Surf ダウンロード ファイル 開く ます',
#  'Android Plus Android Enterprise プラグイン 提供 いる Android標準ブラウザ 利用 SOTI Surf ダウンロード ファイル 開く ます 端末 グループ 作る おく ます 会社 認める アプリ 開く 端末 初期 セットアップ ます 但し MobiControl サーバ チェックイン 最新 正常 性 構成 証明書 不 正常 エンド ポイント PC 特別 端末 グループ 作る 端末 所属 端末 グループ 作成 ます 構成 プロファイル 手動 インストール ない プロファイル ボタン 押す エージェント チェックイン 時刻 登録 実行 ます ルール macOS コンピュータ macOS Windows 更新 インストール 開始 且つ インストール 項 説 明 端末 ファイル名 または フォルダ アップロード なる 端末 Folder サブフォルダ ダウンロード サーバ 社内 文書 ダウンロード 閲覧 できる ます',
#  'Android Plus Android Enterprise プラグイン 提供 いる Android標準ブラウザ 利用 SOTI Surf ダウンロード ファイル 開く ます 端末 グループ 作る おく ます 会社 認める アプリ 開く 端末 初期 セットアップ ます 但し MobiControl サーバ チェックイン 最新 正常 性 構成 証明書 不 正常 エンド ポイント PC 特別 端末 グループ 作る 端末 所属 端末 グループ 作成 ます 構成 プロファイル 手動 インストール ない プロファイル ボタン 押す エージェント チェックイン 時刻 登録 実行 ます ルール macOS コンピュータ macOS Windows 更新 インストール 開始 且つ インストール',
#  'Android Plus Android Enterprise プラグイン 提供 いる Android標準ブラウザ 利用 SOTI Surf ダウンロード ファイル 開く ます 端末 グループ 作る おく ます',
#  'Android Plus Android Enterprise プラグイン 提供 いる Android標準ブラウザ 利用 SOTI Surf ダウンロード ファイル 開く ます 端末 グループ 作る おく ます 会社 認める アプリ 開く 端末 初期 セットアップ ます 但し MobiControl サーバ チェックイン 最新 正常 性 構成 証明書 不 正常 エンド ポイント PC 特別 端末 グループ 作る 端末 所属 端末 グループ 作成 ます']

# %%
import random

# starting words
# text = ["apple", "id"]
text = ['manual', '地理的', '位置']
sentence_finished = False
 
while not sentence_finished:
  # select a random probability threshold  
  r = random.random()
  accumulator = .0

  for word in model[tuple(text[-3:])].keys():
      accumulator += model[tuple(text[-3:])][word]
      # select words that are above the probability threshold
      if accumulator >= r:
          #print(r)
          text.append(word)
          break

  if text[-3:] == [None, None, None]:
      sentence_finished = True
 
result = ' '.join([t for t in text if t])
result
# for x in [t for t in text if t]:
#     print(x)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-9c6038289d3f> in <module>
#      11   accumulator = .0
#      12
# ---> 13   for word in model[tuple(text[-3:])].keys():
#      14       accumulator += model[tuple(text[-3:])][word]
#      15       # select words that are above the probability threshold
#
# KeyboardInterrupt:

# %%
model[tuple(text[-2:])].keys()
# Out:
# dict_keys(['mobicontrol', 'apple', 'android', 'windows', 'linux', '評価', '管理', 'apns', '端末', 'ldap', 'ad', 'プロファイル', 'firewall', '付属', 'コンテンツ', 'ジオフェンス', 'イントラネット', 'セルフサービスポータル', 'exchange', 'コンソール', '危険', 'びっくりマーク', 'パッケージ', '作成', 'スクリプト', '指定', 'アラート', 'システムアラート', '電子メール', 'google', '管理者', 'wns', '設定', '構成', 'bitlocker', 'scep', '単一', 'アプリ', 'エンド', 'eメール', 'ms', 'imap', 'pop', 'apn', 'vpn', 'wifi', 'ランチャー', 'リモート', '更新', '正常', '接続', 'サーバ', '時刻', '監視', 'サポート', 'エージェント', 'ルール', 'ファイル同期', 'アプリカタログルール', 'データ', 'pc', '地理的', '登録', 'ファイル', 'クルマ', '発', 'メール', '無線lan', '通信費', 'メッセージ', 'win', 'バーコードスキャン', 'ウィルス', 'fire', 'nitrodesk', 'タスクスケジューラ', 'bookmark', 'soti', '出荷', 'chrome', 'android標準ブラウザ', 'knox', 'シングルサインオン', 'passcode', 'ブラックリストアプリ', '請求書', 'managed', 'g', 'device', 'profile', 'プラグイン', 'チェックイン', 'ios', 'web', 'iosアプリ', 'ネットワーク', 'カレンダ', '照会', '連絡先', 'airplay', 'グローバル', 'airprint', 'フォント', '管理対象', 'macos', 'ペアレンタルコントロール', 'finder', 'ethernet', 'プロキシ', 'アクセシビリティ', '壁紙', 'dock', 'ログイン', 'プリンタ', '機能拡張', 'filevault', 'カーネル', 'セキュリティ', '省エネルギー', 'ディレクトリ', 'xsan', 'アップデート', 'time', 'ローミング', 'アクティベーション', 'bluetooth', 'vpp', 'sdk', '紛失', 'abm', 'タスクスケジューラー'])

# %%
tuple(text[-2:])
# Out:
# ('端末', 'アクティベーション')

# %%
model[tuple(text[-2:])]['mobicontrol']
# Out:
# 0.011235955056179775

# %%
import nltk
import numpy as np
import random
import string

import bs4 as bs
import urllib.request
import re

# %%
raw_html = urllib.request.urlopen('https://en.wikipedia.org/wiki/Tennis')
raw_html = raw_html.read()

article_html = bs.BeautifulSoup(raw_html, 'lxml')
article_paragraphs = article_html.find_all('p')
article_text = ''

for para in article_paragraphs:
    article_text += para.text

article_text = article_text.lower()

# %%
article_text = re.sub(r'[^A-Za-z. ]', '', article_text)

# %%
ngrams = {}
chars = 3

for i in range(len(article_text)-chars):
    seq = article_text[i:i+chars]
    #print(seq)
    if seq not in ngrams.keys():
        ngrams[seq] = []
    ngrams[seq].append(article_text[i+chars])

# %%
curr_sequence = article_text[0:chars]
curr_sequence
# Out:
# 'ten'

# %%
len(ngrams[curr_sequence])
# Out:
# 172

# %%
random.randrange(len(ngrams[curr_sequence]))
# Out:
# 160

# %%
output = curr_sequence
for i in range(200):
    if curr_sequence not in ngrams.keys():
        break
    possible_chars = ngrams[curr_sequence]
    next_char = possible_chars[random.randrange(len(possible_chars))]
    output += next_char
    curr_sequence = output[len(output)-chars:len(output)]
    print(curr_sequence)
#     break
print(output)
# Out:
# nni
# nis
# is
# s b
#  bo
# bou
# oun
# unt
# nt
# t a
#  al
# alt
# lti
# tin
# inc
# nch
# chw
# hwo
# wom
# ome
# me
# e e
#  ed
# edg
# dgb
# gba
# bas
# ase
# sed
# ed
# d b
#  ba
# bal
# all
# lly
# ly
# y u
#  us
# us
# s d
#  du
# due
# ue
# e c
#  ca
# cal
# all
# lly
# ly
# y o
#  of
# of
# f t
#  th
# the
# he
# e b
#  ba
# bal
# all
# ll
# l a
#  an
# and
# nd
# d o
#  ot
# oth
# the
# he
# e p
#  pr
# pro
# ro
# o g
#  gi
# giv
# ive
# vel
# el.
# l.s
# .sp
# spo
# por
# ora
# rar
# are
# re
# e o
#  op
# opp
# ppo
# pos
# ost
# sti
# tit
# itl
# tle
# le.
# e.
# . t
#  th
# the
# he
# e m
#  mo
# mon
# ong
# ng
# g a
#  an
# and
# nd
# d t
#  th
# the
# he
# e f
#  fe
# fee
# eet
# et
# t w
#  wi
# wit
# ith
# th
# h t
#  th
# the
# he
# e r
#  re
# red
# edi
# dit
# it
# t w
#  wi
# wim
# imb
# mbl
# ble
# le
# e t
#  th
# the
# he
# e t
#  to
# tou
# our
# urn
# rna
# nam
# ame
# men
# ent
# nt.
# t.
# . a
#  an
# and
# nd
# d e
#  en
# eno
# nor
# or
# r h
#  ha
# ham
# amp
# mp
# p w
#  wo
# wor
# orl
# rld
# ld
# d w
#  wo
# won
# on
# n a
#  an
# ang
# nge
# ger
# er
# r o
#  or
# or
# r p
#  pl
# pla
# lay
# aye
# yed
# ed
# ennis bount altinchwome edgbased bally us due cally of the ball and othe pro givel.sporare oppostitle. the mong and the feet with the redit wimble the tournament. and enor hamp world won anger or played

# %%
f_name = '/home/iftekhar/amiebot/amieCore/amie_core/apis/corpus_dashboard/processed_texts.txt'

# %%
data[0]

# %%
ngrams = {}
words = 3

words_tokens = data[1].split()
for i in range(len(words_tokens)-words):
    seq = ' '.join(words_tokens[i:i+words])
    #print(seq)
    if  seq not in ngrams.keys():
        ngrams[seq] = []
    ngrams[seq].append(words_tokens[i+words])

# %%
ngrams
# Out:
# {'apple 製品 mobicontrol': ['v', '管理'],
#  '製品 mobicontrol v': ['manual'],
#  'mobicontrol v manual': ['apple'],
#  'v manual apple': ['製品'],
#  'manual apple 製品': ['apple'],
#  'apple 製品 apple': ['製品'],
#  '製品 apple 製品': ['mobicontrol'],
#  '製品 mobicontrol 管理': ['ios'],
#  'mobicontrol 管理 ios': ['端末'],
#  '管理 ios 端末': ['業務'],
#  'ios 端末 業務': ['アプリ', '活用度'],
#  '端末 業務 アプリ': ['管理'],
#  '業務 アプリ 管理': ['mobicontrol', '最適'],
#  'アプリ 管理 mobicontrol': ['業務'],
#  '管理 mobicontrol 業務': ['アプリ'],
#  'mobicontrol 業務 アプリ': ['管理'],
#  'アプリ 管理 最適': ['ソリューション'],
#  '管理 最適 ソリューション': ['ios'],
#  '最適 ソリューション ios': ['端末'],
#  'ソリューション ios 端末': ['提供'],
#  'ios 端末 提供': ['端末'],
#  '端末 提供 端末': ['ユーザ'],
#  '提供 端末 ユーザ': ['操作'],
#  '端末 ユーザ 操作': ['アプリ', '必要'],
#  'ユーザ 操作 アプリ': ['サイレント'],
#  '操作 アプリ サイレント': ['インストール'],
#  'アプリ サイレント インストール': ['サイレント', 'システム', 'サイレントバージョンアップアプリ'],
#  'サイレント インストール サイレント': ['バージョンアップ'],
#  'インストール サイレント バージョンアップ': ['実現'],
#  'サイレント バージョンアップ 実現': ['端末'],
#  'バージョンアップ 実現 端末': ['ユーザ'],
#  '実現 端末 ユーザ': ['操作'],
#  'ユーザ 操作 必要': ['時間'],
#  '操作 必要 時間': ['数'],
#  '必要 時間 数': ['千'],
#  '時間 数 千': ['端末'],
#  '数 千 端末': ['アプリ'],
#  '千 端末 アプリ': ['配布'],
#  '端末 アプリ 配布': ['バージョンアップ'],
#  'アプリ 配布 バージョンアップ': ['業務改善'],
#  '配布 バージョンアップ 業務改善': ['スピード'],
#  'バージョンアップ 業務改善 スピード': ['社内'],
#  '業務改善 スピード 社内': ['開発'],
#  'スピード 社内 開発': ['app'],
#  '社内 開発 app': ['ストア'],
#  '開発 app ストア': ['公開'],
#  'app ストア 公開': ['アプリ'],
#  'ストア 公開 アプリ': ['端末'],
#  '公開 アプリ 端末': ['配布'],
#  'アプリ 端末 配布': ['インストールアプリ'],
#  '端末 配布 インストールアプリ': ['whytelist'],
#  '配布 インストールアプリ whytelist': ['作成'],
#  'インストールアプリ whytelist 作成': ['業務'],
#  'whytelist 作成 業務': ['関係'],
#  '作成 業務 関係': ['アプリ'],
#  '業務 関係 アプリ': ['起動'],
#  '関係 アプリ 起動': ['禁止'],
#  'アプリ 起動 禁止': ['社内', 'アプリ'],
#  '起動 禁止 社内': ['wifi'],
#  '禁止 社内 wifi': ['vpn'],
#  '社内 wifi vpn': ['リモート', '一斉'],
#  'wifi vpn リモート': ['設定'],
#  'vpn リモート 設定': ['ios'],
#  'リモート 設定 ios': ['端末'],
#  '設定 ios 端末': ['画面', '情報漏洩'],
#  'ios 端末 画面': ['リモートビューリモート', 'コンソール'],
#  '端末 画面 リモートビューリモート': ['ios'],
#  '画面 リモートビューリモート ios': ['端末'],
#  'リモートビューリモート ios 端末': ['画面'],
#  '端末 画面 コンソール': ['表示', 'pc'],
#  '画面 コンソール 表示': ['端末'],
#  'コンソール 表示 端末': ['ユーザ'],
#  '表示 端末 ユーザ': ['アプリ'],
#  '端末 ユーザ アプリ': ['操作', '継承'],
#  'ユーザ アプリ 操作': ['アプリ'],
#  'アプリ 操作 アプリ': ['不具合'],
#  '操作 アプリ 不具合': ['コンソール'],
#  'アプリ 不具合 コンソール': ['画面'],
#  '不具合 コンソール 画面': ['表示'],
#  'コンソール 画面 表示': ['対応'],
#  '画面 表示 対応': ['v'],
#  '表示 対応 v': ['add-on'],
#  '対応 v add-on': ['アプリ'],
#  'v add-on アプリ': ['リモートビュー'],
#  'add-on アプリ リモートビュー': ['実現'],
#  'アプリ リモートビュー 実現': ['v'],
#  'リモートビュー 実現 v': ['アプリ'],
#  '実現 v アプリ': ['リモートビュー'],
#  'v アプリ リモートビュー': ['可能'],
#  'アプリ リモートビュー 可能': ['macos'],
#  'リモートビュー 可能 macos': ['コンピュータ'],
#  '可能 macos コンピュータ': ['システム'],
#  'macos コンピュータ システム': ['環境'],
#  'コンピュータ システム 環境': ['設定'],
#  'システム 環境 設定': ['一括', 'コンソール'],
#  '環境 設定 一括': ['設定'],
#  '設定 一括 設定': ['業務'],
#  '一括 設定 業務': ['アプリ'],
#  '設定 業務 アプリ': ['サイレント'],
#  '業務 アプリ サイレント': ['インストール'],
#  'サイレント インストール システム': ['環境'],
#  'インストール システム 環境': ['設定'],
#  '環境 設定 コンソール': ['一括'],
#  '設定 コンソール 一括': ['設定', '設定'],
#  'コンソール 一括 設定': ['ログイン', 'active'],
#  '一括 設定 ログイン': ['画面'],
#  '設定 ログイン 画面': ['設計'],
#  'ログイン 画面 設計': ['filevault'],
#  '画面 設計 filevault': ['dock'],
#  '設計 filevault dock': ['finder'],
#  'filevault dock finder': ['プリンタ'],
#  'dock finder プリンタ': ['xsan'],
#  'finder プリンタ xsan': ['機能拡張'],
#  'プリンタ xsan 機能拡張': ['面倒'],
#  'xsan 機能拡張 面倒': ['設定'],
#  '機能拡張 面倒 設定': ['コンソール'],
#  '面倒 設定 コンソール': ['一括'],
#  '一括 設定 active': ['directory'],
#  '設定 active directory': ['open'],
#  'active directory open': ['directory'],
#  'directory open directory': ['ネットワーク'],
#  'open directory ネットワーク': ['アカウント'],
#  'directory ネットワーク アカウント': ['コンソール'],
#  'ネットワーク アカウント コンソール': ['リモート'],
#  'アカウント コンソール リモート': ['設定'],
#  'コンソール リモート 設定': ['ユーザ'],
#  'リモート 設定 ユーザ': ['ホームフォルダ'],
#  '設定 ユーザ ホームフォルダ': ['time'],
#  'ユーザ ホームフォルダ time': ['machine'],
#  'ホームフォルダ time machine': ['ファイル'],
#  'time machine ファイル': ['バックアップ'],
#  'machine ファイル バックアップ': ['サーバ'],
#  'ファイル バックアップ サーバ': ['リモート'],
#  'バックアップ サーバ リモート': ['設定'],
#  'サーバ リモート 設定': ['情報漏洩'],
#  'リモート 設定 情報漏洩': ['対策'],
#  '設定 情報漏洩 対策': ['参照'],
#  '情報漏洩 対策 参照': ['どこでもmy'],
#  '対策 参照 どこでもmy': ['mac'],
#  '参照 どこでもmy mac': ['禁止'],
#  'どこでもmy mac 禁止': ['職場'],
#  'mac 禁止 職場': ['コンピュータ'],
#  '禁止 職場 コンピュータ': ['自宅'],
#  '職場 コンピュータ 自宅': ['コンピュータ'],
#  'コンピュータ 自宅 コンピュータ': ['情報流出'],
#  '自宅 コンピュータ 情報流出': ['ネットワークインフラ'],
#  'コンピュータ 情報流出 ネットワークインフラ': ['アカウント'],
#  '情報流出 ネットワークインフラ アカウント': ['自動'],
#  'ネットワークインフラ アカウント 自動': ['設定'],
#  'アカウント 自動 設定': ['社内'],
#  '自動 設定 社内': ['wifi'],
#  '設定 社内 wifi': ['vpn'],
#  'wifi vpn 一斉': ['設定'],
#  'vpn 一斉 設定': ['ios'],
#  '一斉 設定 ios': ['端末'],
#  'ios 端末 情報漏洩': ['対策'],
#  '端末 情報漏洩 対策': ['充実'],
#  '情報漏洩 対策 充実': ['利用'],
#  '対策 充実 利用': ['対策'],
#  '充実 利用 対策': ['ios'],
#  '利用 対策 ios': ['端末'],
#  '対策 ios 端末': ['様々'],
#  'ios 端末 様々': ['情報漏洩'],
#  '端末 様々 情報漏洩': ['対策'],
#  '様々 情報漏洩 対策': ['用意'],
#  '情報漏洩 対策 用意': ['適切'],
#  '対策 用意 適切': ['設定'],
#  '用意 適切 設定': ['前提'],
#  '適切 設定 前提': ['mobicontrol'],
#  '設定 前提 mobicontrol': ['適正'],
#  '前提 mobicontrol 適正': ['設定'],
#  'mobicontrol 適正 設定': ['強制'],
#  '適正 設定 強制': ['適用'],
#  '設定 強制 適用': ['passcode'],
#  '強制 適用 passcode': ['設定'],
#  '適用 passcode 設定': ['強制'],
#  'passcode 設定 強制': ['複雑性'],
#  '設定 強制 複雑性': ['無効'],
#  '強制 複雑性 無効': ['passcode'],
#  '複雑性 無効 passcode': ['入力'],
#  '無効 passcode 入力': ['許容'],
#  'passcode 入力 許容': ['回数'],
#  '入力 許容 回数': ['制限'],
#  '許容 回数 制限': ['ロック'],
#  '回数 制限 ロック': ['siri'],
#  '制限 ロック siri': ['禁止'],
#  'ロック siri 禁止': ['禁止'],
#  'siri 禁止 禁止': ['ロック'],
#  '禁止 禁止 ロック': ['siri'],
#  '禁止 ロック siri': ['連絡'],
#  'ロック siri 連絡': ['電話番号'],
#  'siri 連絡 電話番号': ['icloud'],
#  '連絡 電話番号 icloud': ['ドキュメント'],
#  '電話番号 icloud ドキュメント': ['同期'],
#  'icloud ドキュメント 同期': ['禁止'],
#  'ドキュメント 同期 禁止': ['私物'],
#  '同期 禁止 私物': ['pc'],
#  '禁止 私物 pc': ['デバイス'],
#  '私物 pc デバイス': ['icloud', '情報漏洩'],
#  'pc デバイス icloud': ['アクセス'],
#  'デバイス icloud アクセス': ['会社'],
#  'icloud アクセス 会社': ['ドキュメント'],
#  'アクセス 会社 ドキュメント': ['ダウンロード'],
#  '会社 ドキュメント ダウンロード': ['私物'],
#  'ドキュメント ダウンロード 私物': ['pc'],
#  'ダウンロード 私物 pc': ['デバイス'],
#  'pc デバイス 情報漏洩': ['cookie'],
#  'デバイス 情報漏洩 cookie': ['制限'],
#  '情報漏洩 cookie 制限': ['過去'],
#  'cookie 制限 過去': ['訪問'],
#  '制限 過去 訪問': ['サイト'],
#  '過去 訪問 サイト': ['cookie'],
#  '訪問 サイト cookie': ['制限'],
#  'サイト cookie 制限': ['端末'],
#  'cookie 制限 端末': ['証明'],
#  '制限 端末 証明': ['書'],
#  '端末 証明 書': ['インストール'],
#  '証明 書 インストール': ['メールサーバ'],
#  '書 インストール メールサーバ': ['vpn'],
#  'インストール メールサーバ vpn': ['利用'],
#  'メールサーバ vpn 利用': ['認証'],
#  'vpn 利用 認証': ['会社'],
#  '利用 認証 会社': ['wifi'],
#  '認証 会社 wifi': ['アクセス'],
#  '会社 wifi アクセス': ['機能', 'bluetooth'],
#  'wifi アクセス 機能': ['mobicontrol'],
#  'アクセス 機能 mobicontrol': ['v'],
#  '機能 mobicontrol v': ['追加', '追加'],
#  'mobicontrol v 追加': ['機能', '機能'],
#  'v 追加 機能': ['無償', 'アプリ'],
#  '追加 機能 無償': ['提供'],
#  '機能 無償 提供': ['android標準ブラウザ'],
#  '無償 提供 android標準ブラウザ': ['利用'],
#  '提供 android標準ブラウザ 利用': ['webサイト'],
#  'android標準ブラウザ 利用 webサイト': ['フィルタリング'],
#  '利用 webサイト フィルタリング': ['safari'],
#  'webサイト フィルタリング safari': ['利用'],
#  'フィルタリング safari 利用': ['禁止'],
#  'safari 利用 禁止': ['紛失'],
#  '利用 禁止 紛失': ['対策'],
#  '禁止 紛失 対策': ['アクティベーション'],
#  '紛失 対策 アクティベーション': ['ロック'],
#  '対策 アクティベーション ロック': ['端末'],
#  'アクティベーション ロック 端末': ['アクティベーション'],
#  'ロック 端末 アクティベーション': ['ロック'],
#  '端末 アクティベーション ロック': ['無効', '有効'],
#  'アクティベーション ロック 無効': ['passcode'],
#  'ロック 無効 passcode': ['apple'],
#  '無効 passcode apple': ['id'],
#  'passcode apple id': ['パスワード'],
#  'apple id パスワード': ['拾得', '端末', '入力', 'アクティベーション', '入力', '入力', '入力', '入力'],
#  'id パスワード 拾得': ['端末'],
#  'パスワード 拾得 端末': ['itunes'],
#  '拾得 端末 itunes': ['起動'],
#  '端末 itunes 起動': ['pc'],
#  'itunes 起動 pc': ['接続'],
#  '起動 pc 接続': ['リカバリー'],
#  'pc 接続 リカバリー': ['モード'],
#  '接続 リカバリー モード': ['初期'],
#  'リカバリー モード 初期': ['自分'],
#  'モード 初期 自分': ['物'],
#  '初期 自分 物': ['通常'],
#  '自分 物 通常': ['端末'],
#  '物 通常 端末': ['アクティベーション'],
#  '通常 端末 アクティベーション': ['ロック'],
#  'アクティベーション ロック 有効': ['拾得'],
#  'ロック 有効 拾得': ['方法'],
#  '有効 拾得 方法': ['適用'],
#  '拾得 方法 適用': ['リモート'],
#  '方法 適用 リモート': ['wipe'],
#  '適用 リモート wipe': ['コンソール'],
#  'リモート wipe コンソール': ['端末'],
#  'wipe コンソール 端末': ['工場'],
#  'コンソール 端末 工場': ['出荷'],
#  '端末 工場 出荷': ['状態', '固有'],
#  '工場 出荷 状態': ['端末'],
#  '出荷 状態 端末': ['画面'],
#  '状態 端末 画面': ['メッセージ'],
#  '端末 画面 メッセージ': ['端末'],
#  '画面 メッセージ 端末': ['連絡先'],
#  'メッセージ 端末 連絡先': ['メッセージ'],
#  '端末 連絡先 メッセージ': ['端末'],
#  '連絡先 メッセージ 端末': ['画面'],
#  'メッセージ 端末 画面': ['表示'],
#  '端末 画面 表示': ['端末'],
#  '画面 表示 端末': ['紛失'],
#  '表示 端末 紛失': ['ユーザ'],
#  '端末 紛失 ユーザ': ['自身'],
#  '紛失 ユーザ 自身': ['pc'],
#  'ユーザ 自身 pc': ['タブレット'],
#  '自身 pc タブレット': ['アクセス'],
#  'pc タブレット アクセス': ['b'],
#  'タブレット アクセス b': ['項'],
#  'アクセス b 項': ['c'],
#  'b 項 c': ['項'],
#  '項 c 項': ['実施'],
#  'c 項 実施': ['監視'],
#  '項 実施 監視': ['モード'],
#  '実施 監視 モード': ['会社'],
#  '監視 モード 会社': ['支給'],
#  'モード 会社 支給': ['端末'],
#  '会社 支給 端末': ['監視'],
#  '支給 端末 監視': ['モード'],
#  '端末 監視 モード': ['セット', 'メリット', 'アクティベーション', '端末', '仕組み', '監視'],
#  '監視 モード セット': ['アップ', 'アップ'],
#  'モード セット アップ': ['監視', 'apple'],
#  'セット アップ 監視': ['モード'],
#  'アップ 監視 モード': ['セット'],
#  'セット アップ apple': ['サーバ'],
#  'アップ apple サーバ': ['経由'],
#  'apple サーバ 経由': ['初期'],
#  'サーバ 経由 初期': ['設定'],
#  '経由 初期 設定': ['必要'],
#  '初期 設定 必要': ['ios'],
#  '設定 必要 ios': ['端末'],
#  '必要 ios 端末': ['監視'],
#  'ios 端末 監視': ['モード', 'モード'],
#  '監視 モード メリット': ['情報漏洩'],
#  'モード メリット 情報漏洩': ['対策'],
#  'メリット 情報漏洩 対策': ['目的'],
#  '情報漏洩 対策 目的': ['端末'],
#  '対策 目的 端末': ['設定'],
#  '目的 端末 設定': ['強制'],
#  '端末 設定 強制': ['の'],
#  '設定 強制 の': ['参照'],
#  '強制 の 参照': ['app'],
#  'の 参照 app': ['ストアアプリ'],
#  '参照 app ストアアプリ': ['サイレント'],
#  'app ストアアプリ サイレント': ['インストール'],
#  'ストアアプリ サイレント インストール': ['参照'],
#  'サイレント インストール 参照': ['app'],
#  'インストール 参照 app': ['ストア'],
#  '参照 app ストア': ['の'],
#  'app ストア の': ['ユーザ'],
#  'ストア の ユーザ': ['apple'],
#  'の ユーザ apple': ['id'],
#  'ユーザ apple id': ['端末', '登録', 'vpp'],
#  'apple id 端末': ['紐'],
#  'id 端末 紐': ['端末'],
#  '端末 紐 端末': ['ユーザ'],
#  '紐 端末 ユーザ': ['アプリ'],
#  'ユーザ アプリ 継承': ['有償'],
#  'アプリ 継承 有償': ['アプリ'],
#  '継承 有償 アプリ': ['新規'],
#  '有償 アプリ 新規': ['購入', '購入'],
#  'アプリ 新規 購入': ['不要', '不要'],
#  '新規 購入 不要': ['apple', 'app'],
#  '購入 不要 apple': ['id'],
#  '不要 apple id': ['管理'],
#  'apple id 管理': ['不要', '回避', '不要'],
#  'id 管理 不要': ['端末', 'オプション'],
#  '管理 不要 端末': ['監視'],
#  '不要 端末 監視': ['モード'],
#  '監視 モード アクティベーション': ['初期'],
#  'モード アクティベーション 初期': ['設定'],
#  'アクティベーション 初期 設定': ['apple'],
#  '初期 設定 apple': ['apple'],
#  '設定 apple apple': ['id'],
#  'apple apple id': ['登録'],
#  'apple id 登録': ['監視', '使用', 'icloud', '初期'],
#  'id 登録 監視': ['モード'],
#  '登録 監視 モード': ['端末'],
#  '監視 モード 端末': ['apple', '監視', 'vpp', 'apple'],
#  'モード 端末 apple': ['id', 'id'],
#  '端末 apple id': ['登録', '管理', '当該', '管理'],
#  'id 登録 使用': ['app'],
#  '登録 使用 app': ['ストア'],
#  '使用 app ストア': ['アプリ'],
#  'app ストア アプリ': ['デバイス', '社内', '企業', 'ダウンロード', '追加', '追加'],
#  'ストア アプリ デバイス': ['ベース'],
#  'アプリ デバイス ベース': ['vpp'],
#  'デバイス ベース vpp': ['アプリ'],
#  'ベース vpp アプリ': ['アプリカタログ'],
#  'vpp アプリ アプリカタログ': ['掲載'],
#  'アプリ アプリカタログ 掲載': ['配布'],
#  'アプリカタログ 掲載 配布': ['icloud'],
#  '掲載 配布 icloud': ['アクセス'],
#  '配布 icloud アクセス': ['同等'],
#  'icloud アクセス 同等': ['操作'],
#  'アクセス 同等 操作': ['煩雑'],
#  '同等 操作 煩雑': ['端末'],
#  '操作 煩雑 端末': ['apple'],
#  '煩雑 端末 apple': ['id'],
#  'id 管理 回避': ['端末'],
#  '管理 回避 端末': ['操作'],
#  '回避 端末 操作': ['端末'],
#  '端末 操作 端末': ['ユーザ'],
#  '操作 端末 ユーザ': ['apple'],
#  '端末 ユーザ apple': ['id'],
#  'id 登録 icloud': ['アクセス'],
#  '登録 icloud アクセス': ['apple'],
#  'icloud アクセス apple': ['id'],
#  'アクセス apple id': ['パスワード'],
#  'id パスワード 端末': ['地理的'],
#  'パスワード 端末 地理的': ['位置'],
#  '端末 地理的 位置': ['表示', 'コンソール'],
#  '地理的 位置 表示': ['iphone'],
#  '位置 表示 iphone': ['同等'],
#  '表示 iphone 同等': ['機能'],
#  'iphone 同等 機能': ['アクティベーション'],
#  '同等 機能 アクティベーション': ['ロック'],
#  '機能 アクティベーション ロック': ['強制'],
#  'アクティベーション ロック 強制': ['端末'],
#  'ロック 強制 端末': ['ユーザ'],
#  '強制 端末 ユーザ': ['アクティベーション'],
#  '端末 ユーザ アクティベーション': ['ロック'],
#  'ユーザ アクティベーション ロック': ['無効化'],
#  'アクティベーション ロック 無効化': ['禁止'],
#  'ロック 無効化 禁止': ['参照'],
#  '無効化 禁止 参照': ['アクティベーション'],
#  '禁止 参照 アクティベーション': ['ロック'],
#  '参照 アクティベーション ロック': ['バイパス'],
#  'アクティベーション ロック バイパス': ['盗難', 'コード'],
#  'ロック バイパス 盗難': ['紛失'],
#  'バイパス 盗難 紛失': ['端末'],
#  '盗難 紛失 端末': ['wipe'],
#  '紛失 端末 wipe': ['アクティベーション'],
#  '端末 wipe アクティベーション': ['apple'],
#  'wipe アクティベーション apple': ['id'],
#  'アクティベーション apple id': ['パスワード'],
#  'id パスワード 入力': ['mobicontrol', 'ポップアップ', 'ユーザベース', '要求', '代替', '要求'],
#  'パスワード 入力 mobicontrol': ['登録'],
#  '入力 mobicontrol 登録': ['端末'],
#  'mobicontrol 登録 端末': ['設定'],
#  '登録 端末 設定': ['リセット'],
#  '端末 設定 リセット': ['便利'],
#  '設定 リセット 便利': ['盗難'],
#  'リセット 便利 盗難': ['紛失'],
#  '便利 盗難 紛失': ['可能性'],
#  '盗難 紛失 可能性': ['端末'],
#  '紛失 可能性 端末': ['バイパス'],
#  '可能性 端末 バイパス': ['端末'],
#  '端末 バイパス 端末': ['要求'],
#  'バイパス 端末 要求': ['アクティベーション'],
#  '端末 要求 アクティベーション': ['プロセス'],
#  '要求 アクティベーション プロセス': ['apple'],
#  'アクティベーション プロセス apple': ['id'],
#  'プロセス apple id': ['パスワード'],
#  'id パスワード アクティベーション': ['ロック'],
#  'パスワード アクティベーション ロック': ['バイパス'],
#  'ロック バイパス コード': ['入力'],
#  'バイパス コード 入力': ['必須'],
#  'コード 入力 必須': ['端末'],
#  '入力 必須 端末': ['操作'],
#  '必須 端末 操作': ['mobicontrol'],
#  '端末 操作 mobicontrol': ['登録', '登録'],
#  '操作 mobicontrol 登録': ['解除', '解除'],
#  'mobicontrol 登録 解除': ['禁止', '禁止'],
#  '登録 解除 禁止': ['手動', 'ホスト'],
#  '解除 禁止 手動': ['dep'],
#  '禁止 手動 dep': ['登録'],
#  '手動 dep 登録': ['端末'],
#  'dep 登録 端末': ['アクティベーション'],
#  '登録 端末 アクティベーション': ['日間'],
#  '端末 アクティベーション 日間': ['登録'],
#  'アクティベーション 日間 登録': ['解除'],
#  '日間 登録 解除': ['可能'],
#  '登録 解除 可能': ['apns'],
#  '解除 可能 apns': ['端末'],
#  '可能 apns 端末': ['通常'],
#  'apns 端末 通常': ['mobicontrol'],
#  '端末 通常 mobicontrol': ['サーバ'],
#  '通常 mobicontrol サーバ': ['接続'],
#  'mobicontrol サーバ 接続': ['mobicontrol', '端末', '通常'],
#  'サーバ 接続 mobicontrol': ['サーバ'],
#  '接続 mobicontrol サーバ': ['端末'],
#  'mobicontrol サーバ 端末': ['アクセス'],
#  'サーバ 端末 アクセス': ['通信'],
#  '端末 アクセス 通信': ['セッション'],
#  'アクセス 通信 セッション': ['有馬線'],
#  '通信 セッション 有馬線': ['ios'],
#  'セッション 有馬線 ios': ['端末'],
#  '有馬線 ios 端末': ['出荷'],
#  'ios 端末 出荷': ['mdm'],
#  '端末 出荷 mdm': ['プロトコル'],
#  '出荷 mdm プロトコル': ['名前'],
#  'mdm プロトコル 名前': ['プログラム'],
#  'プロトコル 名前 プログラム': ['標準'],
#  '名前 プログラム 標準': ['搭載'],
#  'プログラム 標準 搭載': ['mdm'],
#  '標準 搭載 mdm': ['プロトコル'],
#  '搭載 mdm プロトコル': ['apns'],
#  'mdm プロトコル apns': ['apple'],
#  'プロトコル apns apple': ['push'],
#  'apns apple push': ['notification'],
#  'apple push notification': ['service'],
#  'push notification service': ['通知'],
#  'notification service 通知': ['notice'],
#  'service 通知 notice': ['常時'],
#  '通知 notice 常時': ['設定'],
#  'notice 常時 設定': ['端末'],
#  '常時 設定 端末': ['リモートロック'],
#  '設定 端末 リモートロック': ['紛失'],
#  '端末 リモートロック 紛失': ['モード'],
#  'リモートロック 紛失 モード': ['wipe'],
#  '紛失 モード wipe': ['初期化'],
#  'モード wipe 初期化': ['コマンド'],
#  'wipe 初期化 コマンド': ['apns'],
#  '初期化 コマンド apns': ['経由'],
#  'コマンド apns 経由': ['チェックイン'],
#  'apns 経由 チェックイン': ['要求'],
#  '経由 チェックイン 要求': ['端末'],
#  'チェックイン 要求 端末': ['チェックイン'],
#  '要求 端末 チェックイン': ['要求'],
#  '端末 チェックイン 要求': ['mobicontrol', '実現'],
#  'チェックイン 要求 mobicontrol': ['サーバ'],
#  '要求 mobicontrol サーバ': ['チェックイン'],
#  'mobicontrol サーバ チェックイン': ['コマンド', '通常'],
#  'サーバ チェックイン コマンド': ['端末'],
#  'チェックイン コマンド 端末': ['構成'],
#  'コマンド 端末 構成': ['プロファイル'],
#  '端末 構成 プロファイル': ['ルール', '作成', '作成'],
#  '構成 プロファイル ルール': ['展開'],
#  'プロファイル ルール 展開': ['の'],
#  'ルール 展開 の': ['端末'],
#  '展開 の 端末': ['チェックイン'],
#  'の 端末 チェックイン': ['要求'],
#  'チェックイン 要求 実現': ['端末'],
#  '要求 実現 端末': ['mobicontrol'],
#  '実現 端末 mobicontrol': ['サーバ'],
#  '端末 mobicontrol サーバ': ['チェックイン', '接続', '登録'],
#  'サーバ チェックイン 通常': ['https'],
#  'チェックイン 通常 https': ['tcp'],
#  '通常 https tcp': ['コール', 'コール'],
#  'https tcp コール': ['ルール', '端末'],
#  'tcp コール ルール': ['アプリカタログルール'],
#  'コール ルール アプリカタログルール': ['インストール'],
#  'ルール アプリカタログルール インストール': ['アプリ'],
#  'アプリカタログルール インストール アプリ': ['情報'],
#  'インストール アプリ 情報': ['オブジェクト'],
#  'アプリ 情報 オブジェクト': ['端末'],
#  '情報 オブジェクト 端末': ['チェックアウト'],
#  'オブジェクト 端末 チェックアウト': ['mobicontrol'],
#  '端末 チェックアウト mobicontrol': ['エージェントアプリ'],
#  'チェックアウト mobicontrol エージェントアプリ': ['一つ'],
#  'mobicontrol エージェントアプリ 一つ': ['mobicontrol'],
#  'エージェントアプリ 一つ mobicontrol': ['エージェント'],
#  '一つ mobicontrol エージェント': ['追加'],
#  'mobicontrol エージェント 追加': ['インストール'],
#  'エージェント 追加 インストール': ['端末'],
#  '追加 インストール 端末': ['付加'],
#  'インストール 端末 付加': ['機能'],
#  '端末 付加 機能': ['追加'],
#  '付加 機能 追加': ['端末'],
#  '機能 追加 端末': ['ユーザ'],
#  '追加 端末 ユーザ': ['mobicontrol'],
#  '端末 ユーザ mobicontrol': ['エージェント'],
#  'ユーザ mobicontrol エージェント': ['起動'],
#  'mobicontrol エージェント 起動': ['mobicontrol'],
#  'エージェント 起動 mobicontrol': ['サーバ'],
#  '起動 mobicontrol サーバ': ['接続'],
#  'サーバ 接続 端末': ['mobicontrol'],
#  '接続 端末 mobicontrol': ['サーバ'],
#  'サーバ 接続 通常': ['https'],
#  '接続 通常 https': ['tcp'],
#  'tcp コール 端末': ['画像'],
#  'コール 端末 画像': ['イメージ'],
#  '端末 画像 イメージ': ['コンソール'],
#  '画像 イメージ コンソール': ['表示'],
#  'イメージ コンソール 表示': ['画像'],
#  'コンソール 表示 画像': ['変化'],
#  '表示 画像 変化': ['リアルタイム'],
#  '画像 変化 リアルタイム': ['表示'],
#  '変化 リアルタイム 表示': ['端末'],
#  'リアルタイム 表示 端末': ['地理的'],
#  '表示 端末 地理的': ['位置'],
#  '地理的 位置 コンソール': ['地図'],
#  '位置 コンソール 地図': ['表示'],
#  'コンソール 地図 表示': ['mdm'],
#  '地図 表示 mdm': ['プロトコル'],
#  '表示 mdm プロトコル': ['端末'],
#  'mdm プロトコル 端末': ['ステータス'],
#  'プロトコル 端末 ステータス': ['情報'],
#  '端末 ステータス 情報': ['長文'],
#  'ステータス 情報 長文': ['メッセージ'],
#  '情報 長文 メッセージ': ['端末'],
#  '長文 メッセージ 端末': ['mdm'],
#  'メッセージ 端末 mdm': ['プロトコル'],
#  '端末 mdm プロトコル': ['チェックイン'],
#  'mdm プロトコル チェックイン': ['mobicontrol'],
#  'プロトコル チェックイン mobicontrol': ['エージェント'],
#  'チェックイン mobicontrol エージェント': ['接続'],
#  'mobicontrol エージェント 接続': ['送受'],
#  'エージェント 接続 送受': ['オブジェクト'],
#  '接続 送受 オブジェクト': ['vpp'],
#  '送受 オブジェクト vpp': ['アプリカタログルール'],
#  'オブジェクト vpp アプリカタログルール': ['適用'],
#  'vpp アプリカタログルール 適用': ['ios'],
#  'アプリカタログルール 適用 ios': ['端末'],
#  '適用 ios 端末': ['app'],
#  'ios 端末 app': ['catalog'],
#  '端末 app catalog': ['名前'],
#  'app catalog 名前': ['ikon'],
#  'catalog 名前 ikon': ['ホーム'],
#  '名前 ikon ホーム': ['画面'],
#  'ikon ホーム 画面': ['表示'],
#  'ホーム 画面 表示': ['アプリ'],
#  '画面 表示 アプリ': ['名前'],
#  '表示 アプリ 名前': ['ikon'],
#  'アプリ 名前 ikon': ['表示'],
#  '名前 ikon 表示': ['アプリ'],
#  'ikon 表示 アプリ': ['ダウンロード'],
#  '表示 アプリ ダウンロード': ['url'],
#  'アプリ ダウンロード url': ['端末'],
#  'ダウンロード url 端末': ['ユーザ'],
#  'url 端末 ユーザ': ['タップ'],
#  '端末 ユーザ タップ': ['業務'],
#  'ユーザ タップ 業務': ['アプリ'],
#  'タップ 業務 アプリ': ['ダウンロード'],
#  '業務 アプリ ダウンロード': ['インストール'],
#  'アプリ ダウンロード インストール': ['アプリ'],
#  'ダウンロード インストール アプリ': ['app'],
#  'インストール アプリ app': ['ストア'],
#  'アプリ app ストア': ['アプリ'],
#  'ストア アプリ 社内': ['限り'],
#  'アプリ 社内 限り': ['社内'],
#  '社内 限り 社内': ['サーバ'],
#  '限り 社内 サーバ': ['ダウンロード'],
#  '社内 サーバ ダウンロード': ['アプリ'],
#  'サーバ ダウンロード アプリ': ['エンタープライズアプリ'],
#  'ダウンロード アプリ エンタープライズアプリ': ['app'],
#  'アプリ エンタープライズアプリ app': ['ストア'],
#  'エンタープライズアプリ app ストア': ['アプリ'],
#  'ストア アプリ 企業': ['団体'],
#  'アプリ 企業 団体': ['vpp'],
#  '企業 団体 vpp': ['volume'],
#  '団体 vpp volume': ['purchase'],
#  'vpp volume purchase': ['planning'],
#  'volume purchase planning': ['まとめ買い'],
#  'purchase planning まとめ買い': ['契約'],
#  'planning まとめ買い 契約': ['vpp'],
#  'まとめ買い 契約 vpp': ['契約'],
#  '契約 vpp 契約': ['購入'],
#  'vpp 契約 購入': ['アプリ'],
#  '契約 購入 アプリ': ['個別'],
#  '購入 アプリ 個別': ['端末'],
#  'アプリ 個別 端末': ['ユーザ'],
#  '個別 端末 ユーザ': ['費用'],
#  '端末 ユーザ 費用': ['負担'],
#  'ユーザ 費用 負担': ['の'],
#  '費用 負担 の': ['企業'],
#  '負担 の 企業': ['団体'],
#  'の 企業 団体': ['費用'],
#  '企業 団体 費用': ['負担'],
#  '団体 費用 負担': ['vpp'],
#  '費用 負担 vpp': ['アプリ'],
#  '負担 vpp アプリ': ['帰属'],
#  'vpp アプリ 帰属': ['端末'],
#  'アプリ 帰属 端末': ['デバイス'],
#  '帰属 端末 デバイス': ['ユーザ'],
#  '端末 デバイス ユーザ': ['選択肢'],
#  'デバイス ユーザ 選択肢': ['デバイス'],
#  'ユーザ 選択肢 デバイス': ['ベース'],
#  '選択肢 デバイス ベース': ['端末'],
#  'デバイス ベース 端末': ['ユーザ'],
#  'ベース 端末 ユーザ': ['端末'],
#  '端末 ユーザ 端末': ['apple', '紛失'],
#  'ユーザ 端末 apple': ['id'],
#  'apple id 当該': ['アプリ'],
#  'id 当該 アプリ': ['ユーザベース'],
#  '当該 アプリ ユーザベース': ['ユーザ'],
#  'アプリ ユーザベース ユーザ': ['端末'],
#  'ユーザベース ユーザ 端末': ['当該'],
#  'ユーザ 端末 当該': ['アプリ'],
#  '端末 当該 アプリ': ['有償'],
#  '当該 アプリ 有償': ['アプリ'],
#  'アプリ 有償 アプリ': ['新規'],
#  '購入 不要 app': ['ストア'],
#  '不要 app ストア': ['アプリ'],
#  'ストア アプリ ダウンロード': ['端末'],
#  'アプリ ダウンロード 端末': ['ポップアップ'],
#  'ダウンロード 端末 ポップアップ': ['違い'],
#  '端末 ポップアップ 違い': ['監視'],
#  'ポップアップ 違い 監視': ['モード'],
#  '違い 監視 モード': ['端末'],
#  'モード 端末 監視': ['モード'],
#  'モード 端末 vpp': ['契約'],
#  '端末 vpp 契約': ['アプリポップアップ'],
#  'vpp 契約 アプリポップアップ': ['無し'],
#  '契約 アプリポップアップ 無し': ['サイレント'],
#  'アプリポップアップ 無し サイレント': ['インストール'],
#  '無し サイレント インストール': ['可能'],
#  'サイレント インストール 可能': ['インストール'],
#  'インストール 可能 インストール': ['メッセージ'],
#  '可能 インストール メッセージ': ['ポップアップ'],
#  'インストール メッセージ ポップアップ': ['vpp'],
#  'メッセージ ポップアップ vpp': ['契約'],
#  'ポップアップ vpp 契約': ['アプリ'],
#  'vpp 契約 アプリ': ['apple'],
#  '契約 アプリ apple': ['id'],
#  'アプリ apple id': ['パスワード'],
#  'パスワード 入力 ポップアップ': ['ポップアップ'],
#  '入力 ポップアップ ポップアップ': ['インストール'],
#  'ポップアップ ポップアップ インストール': ['メッセージ'],
#  'ポップアップ インストール メッセージ': ['apple'],
#  'インストール メッセージ apple': ['id'],
#  'メッセージ apple id': ['パスワード'],
#  'パスワード 入力 ユーザベース': ['アプリ'],
#  '入力 ユーザベース アプリ': ['ユーザ'],
#  'ユーザベース アプリ ユーザ': ['apple'],
#  'アプリ ユーザ apple': ['id'],
#  'apple id vpp': ['契約'],
#  'id vpp 契約': ['紐'],
#  'vpp 契約 紐': ['ポップアップ'],
#  '契約 紐 ポップアップ': ['初回'],
#  '紐 ポップアップ 初回': ['dep'],
#  'ポップアップ 初回 dep': ['device'],
#  '初回 dep device': ['enrollment'],
#  'dep device enrollment': ['program'],
#  'device enrollment program': ['ios'],
#  'enrollment program ios': ['端末'],
#  'program ios 端末': ['監視'],
#  '監視 モード 仕組み': ['監視'],
#  'モード 仕組み 監視': ['モード'],
#  '仕組み 監視 モード': ['の'],
#  '監視 モード の': ['端末'],
#  'モード の 端末': ['初期'],
#  'の 端末 初期': ['設定'],
#  '端末 初期 設定': ['アクティベーション'],
#  '初期 設定 アクティベーション': ['端末'],
#  '設定 アクティベーション 端末': ['工場'],
#  'アクティベーション 端末 工場': ['出荷'],
#  '工場 出荷 固有': ['シリアル番号'],
#  '出荷 固有 シリアル番号': ['シリアル番号'],
#  '固有 シリアル番号 シリアル番号': ['apple'],
#  'シリアル番号 シリアル番号 apple': ['アクティベーション'],
#  'シリアル番号 apple アクティベーション': ['サーバ'],
#  'apple アクティベーション サーバ': ['登録', '登録', 'apple', 'apple'],
#  'アクティベーション サーバ 登録': ['通常', '必要'],
#  'サーバ 登録 通常': ['初期'],
#  '登録 通常 初期': ['設定'],
#  '通常 初期 設定': ['シリアル番号'],
#  '初期 設定 シリアル番号': ['mdm', 'mdm'],
#  '設定 シリアル番号 mdm': ['サーバ', 'サーバ'],
#  'シリアル番号 mdm サーバ': ['url', 'url'],
#  'mdm サーバ url': ['紐', '紐'],
#  'サーバ url 紐': ['apple', '端末', '通常'],
#  'url 紐 apple': ['id'],
#  '紐 apple id': ['登録'],
#  'id 登録 初期': ['設定'],
#  '登録 初期 設定': ['シリアル番号'],
#  'url 紐 端末': ['mdm'],
#  '紐 端末 mdm': ['サーバ'],
#  '端末 mdm サーバ': ['自動的'],
#  'mdm サーバ 自動的': ['アクセス'],
#  'サーバ 自動的 アクセス': ['リダイレクト'],
#  '自動的 アクセス リダイレクト': ['mdm'],
#  'アクセス リダイレクト mdm': ['サーバ'],
#  'リダイレクト mdm サーバ': ['登録'],
#  'mdm サーバ 登録': ['端末'],
#  'サーバ 登録 端末': ['用意'],
#  '登録 端末 用意': ['構成'],
#  '端末 用意 構成': ['プロファイル'],
#  '用意 構成 プロファイル': ['ダウンロード'],
#  '構成 プロファイル ダウンロード': ['dep'],
#  'プロファイル ダウンロード dep': ['実現'],
#  'ダウンロード dep 実現': ['当該'],
#  'dep 実現 当該': ['端末'],
#  '実現 当該 端末': ['シリアル番号'],
#  '当該 端末 シリアル番号': ['dep'],
#  '端末 シリアル番号 dep': ['対象', 'サーバ'],
#  'シリアル番号 dep 対象': ['apple'],
#  'dep 対象 apple': ['アクティベーション'],
#  '対象 apple アクティベーション': ['サーバ'],
#  'サーバ 登録 必要': ['登録'],
#  '登録 必要 登録': ['誰'],
#  '必要 登録 誰': ['dep'],
#  '登録 誰 dep': ['登録'],
#  '誰 dep 登録': ['方法'],
#  'dep 登録 方法': ['種類'],
#  '登録 方法 種類': ['abm'],
#  '方法 種類 abm': ['apple'],
#  '種類 abm apple': ['business'],
#  'abm apple business': ['manager'],
#  'apple business manager': ['略'],
#  'business manager 略': ['対象'],
#  'manager 略 対象': ['端末'],
#  '略 対象 端末': ['携帯電話'],
#  '対象 端末 携帯電話': ['会社'],
#  '端末 携帯電話 会社': ['直接'],
#  '携帯電話 会社 直接': ['購入'],
#  '会社 直接 購入': ['端末'],
#  '直接 購入 端末': ['dep'],
#  '購入 端末 dep': ['販売店', '販売店'],
#  '端末 dep 販売店': ['id', 'id'],
#  'dep 販売店 id': ['販売店', '販売店'],
#  '販売店 id 販売店': ['購入', '購入'],
#  'id 販売店 購入': ['端末', '端末'],
#  '販売店 購入 端末': ['dep', '購入'],
#  '購入 端末 購入': ['済'],
#  '端末 購入 済': ['端末'],
#  '購入 済 端末': ['監視'],
#  '済 端末 監視': ['モード'],
#  '監視 モード 監視': ['モード'],
#  'モード 監視 モード': ['変更', 'ad'],
#  '監視 モード 変更': ['端末'],
#  'モード 変更 端末': ['端末'],
#  '変更 端末 端末': ['シリアル番号'],
#  '端末 端末 シリアル番号': ['dep', 'mobicontrol'],
#  'シリアル番号 dep サーバ': ['登録'],
#  'dep サーバ 登録': ['販売店', '予定'],
#  'サーバ 登録 販売店': ['購入'],
#  '登録 販売店 購入': ['利用'],
#  '販売店 購入 利用': ['企業'],
#  '購入 利用 企業': ['団体'],
#  '利用 企業 団体': ['保有'],
#  '企業 団体 保有': ['端末'],
#  '団体 保有 端末': ['シリアル番号'],
#  '保有 端末 シリアル番号': ['端末'],
#  '端末 シリアル番号 端末': ['登録'],
#  'シリアル番号 端末 登録': ['ルール'],
#  '端末 登録 ルール': ['配置'],
#  '登録 ルール 配置': ['mobicontrol'],
#  'ルール 配置 mobicontrol': ['コンソール'],
#  '配置 mobicontrol コンソール': ['アクセス権限'],
#  'mobicontrol コンソール アクセス権限': ['実行'],
#  'コンソール アクセス権限 実行': ['不要'],
#  'アクセス権限 実行 不要': ['dep'],
#  '実行 不要 dep': ['サーバ'],
#  '不要 dep サーバ': ['登録'],
#  'サーバ 登録 予定': ['端末'],
#  '登録 予定 端末': ['端末'],
#  '予定 端末 端末': ['シリアル番号'],
#  '端末 シリアル番号 mobicontrol': ['サーバ'],
#  'シリアル番号 mobicontrol サーバ': ['url'],
#  'mobicontrol サーバ url': ['紐'],
#  'url 紐 通常': ['端末'],
#  '紐 通常 端末': ['初期化'],
#  '通常 端末 初期化': ['アクティベーション'],
#  '端末 初期化 アクティベーション': ['apple'],
#  '初期化 アクティベーション apple': ['アクティベーション'],
#  'アクティベーション apple アクティベーション': ['サーバ'],
#  'アクティベーション サーバ apple': ['id', 'id'],
#  'サーバ apple id': ['パスワード', 'パスワード'],
#  'パスワード 入力 要求': ['監視', 'ad', '監視'],
#  '入力 要求 監視': ['モード', 'モード'],
#  '要求 監視 モード': ['端末', '設定'],
#  '管理 不要 オプション': ['当該'],
#  '不要 オプション 当該': ['端末'],
#  'オプション 当該 端末': ['リモート'],
#  '当該 端末 リモート': ['wipe'],
#  '端末 リモート wipe': ['初期化'],
#  'リモート wipe 初期化': ['アクティベーション'],
#  'wipe 初期化 アクティベーション': ['mobicontrol'],
#  '初期化 アクティベーション mobicontrol': ['サーバ'],
#  'アクティベーション mobicontrol サーバ': ['アクティベーション'],
#  'mobicontrol サーバ アクティベーション': ['バイパス'],
#  'サーバ アクティベーション バイパス': ['コード'],
#  'アクティベーション バイパス コード': ['端末'],
#  'バイパス コード 端末': ['端末'],
#  'コード 端末 端末': ['apple'],
#  '端末 端末 apple': ['アクティベーション'],
#  '端末 apple アクティベーション': ['サーバ'],
#  'パスワード 入力 代替': ['sdk'],
#  '入力 代替 sdk': ['ios'],
#  '代替 sdk ios': ['os'],
#  'sdk ios os': ['端末'],
#  'ios os 端末': ['インストール'],
#  'os 端末 インストール': ['アプリ'],
#  '端末 インストール アプリ': ['add-on'],
#  'インストール アプリ add-on': ['ios'],
#  'アプリ add-on ios': ['端末'],
#  'add-on ios 端末': ['業務'],
#  '端末 業務 活用度': ['アプリ'],
#  '業務 活用度 アプリ': ['操作'],
#  '活用度 アプリ 操作': ['端末'],
#  'アプリ 操作 端末': ['画面'],
#  '操作 端末 画面': ['コンソール'],
#  '画面 コンソール pc': ['画面'],
#  'コンソール pc 画面': ['リモート'],
#  'pc 画面 リモート': ['表示'],
#  '画面 リモート 表示': ['アプリ'],
#  'リモート 表示 アプリ': ['操作'],
#  '表示 アプリ 操作': ['指導'],
#  'アプリ 操作 指導': ['不具合'],
#  '操作 指導 不具合': ['発見'],
#  '指導 不具合 発見': ['アプリ'],
#  '不具合 発見 アプリ': ['配下'],
#  '発見 アプリ 配下': ['サブフォルダ'],
#  'アプリ 配下 サブフォルダ': ['データファイル', '表示'],
#  '配下 サブフォルダ データファイル': ['ファイルサーバ'],
#  'サブフォルダ データファイル ファイルサーバ': ['ファイルサーバ'],
#  'データファイル ファイルサーバ ファイルサーバ': ['端末'],
#  'ファイルサーバ ファイルサーバ 端末': ['必要'],
#  'ファイルサーバ 端末 必要': ['データ'],
#  '端末 必要 データ': ['アプリ'],
#  '必要 データ アプリ': ['作成'],
#  'データ アプリ 作成': ['サーバ'],
#  'アプリ 作成 サーバ': ['ファイル同期'],
#  '作成 サーバ ファイル同期': ['手配'],
#  'サーバ ファイル同期 手配': ['簡単'],
#  'ファイル同期 手配 簡単': ['サーバ'],
#  '手配 簡単 サーバ': ['端末'],
#  '簡単 サーバ 端末': ['サブフォルダ'],
#  'サーバ 端末 サブフォルダ': ['自動的'],
#  '端末 サブフォルダ 自動的': ['コンソール'],
#  'サブフォルダ 自動的 コンソール': ['pc'],
#  '自動的 コンソール pc': ['エクスプロラツール'],
#  'コンソール pc エクスプロラツール': ['端末'],
#  'pc エクスプロラツール 端末': ['アプリ'],
#  'エクスプロラツール 端末 アプリ': ['配下'],
#  '端末 アプリ 配下': ['サブフォルダ'],
#  '配下 サブフォルダ 表示': ['コンソール'],
#  'サブフォルダ 表示 コンソール': ['pc'],
#  '表示 コンソール pc': ['間'],
#  'コンソール pc 間': ['ファイル'],
#  'pc 間 ファイル': ['送受'],
#  '間 ファイル 送受': ['更新'],
#  'ファイル 送受 更新': ['アプリ'],
#  '送受 更新 アプリ': ['デバッグ'],
#  '更新 アプリ デバッグ': ['無償'],
#  'アプリ デバッグ 無償': ['ad'],
#  'デバッグ 無償 ad': ['active'],
#  '無償 ad active': ['directory'],
#  'ad active directory': ['連携'],
#  'active directory 連携': ['ios'],
#  'directory 連携 ios': ['端末'],
#  '連携 ios 端末': ['mobicontrol'],
#  'ios 端末 mobicontrol': ['サーバ'],
#  'mobicontrol サーバ 登録': ['本人認証', 'プロセス'],
#  'サーバ 登録 本人認証': ['端末'],
#  '登録 本人認証 端末': ['ユーザ'],
#  '本人認証 端末 ユーザ': ['adds'],
#  '端末 ユーザ adds': ['active'],
#  'ユーザ adds active': ['directory'],
#  'adds active directory': ['domain'],
#  'active directory domain': ['service'],
#  'directory domain service': ['ユーザ名'],
#  'domain service ユーザ名': ['パスワード'],
#  'service ユーザ名 パスワード': ['入力'],
#  'ユーザ名 パスワード 入力': ['要求'],
#  '入力 要求 ad': ['ds'],
#  '要求 ad ds': ['認証'],
#  'ad ds 認証': ['端末'],
#  'ds 認証 端末': ['登録'],
#  '認証 端末 登録': ['メリット'],
#  '端末 登録 メリット': ['adds'],
#  '登録 メリット adds': ['認証'],
#  'メリット adds 認証': ['端末'],
#  'adds 認証 端末': ['構成', 'モード'],
#  '認証 端末 構成': ['プロファイル'],
#  '構成 プロファイル 作成': ['マクロ', '不要'],
#  'プロファイル 作成 マクロ': ['文字列'],
#  '作成 マクロ 文字列': ['%'],
#  'マクロ 文字列 %': ['enrolledupn', 'enrolledupn'],
#  '文字列 % enrolledupn': ['%', '%'],
#  '% enrolledupn %': ['メール', '個別'],
#  'enrolledupn % メール': ['adds'],
#  '% メール adds': ['認証'],
#  'メール adds 認証': ['要求'],
#  'adds 認証 要求': ['vpn'],
#  '認証 要求 vpn': ['wifi'],
#  '要求 vpn wifi': ['構成'],
#  'vpn wifi 構成': ['プロファイル'],
#  'wifi 構成 プロファイル': ['端末'],
#  '構成 プロファイル 端末': ['ユーザ'],
#  'プロファイル 端末 ユーザ': ['upn'],
#  '端末 ユーザ upn': ['変更'],
#  'ユーザ upn 変更': ['端末'],
#  'upn 変更 端末': ['配布'],
#  '変更 端末 配布': ['マクロ'],
#  '端末 配布 マクロ': ['文字列'],
#  '配布 マクロ 文字列': ['%'],
#  'enrolledupn % 個別': ['端末'],
#  '% 個別 端末': ['構成'],
#  '個別 端末 構成': ['プロファイル'],
#  'プロファイル 作成 不要': ['端末'],
#  '作成 不要 端末': ['ユーザ'],
#  '不要 端末 ユーザ': ['端末'],
#  'ユーザ 端末 紛失': ['デバイス'],
#  '端末 紛失 デバイス': ['スマホ'],
#  '紛失 デバイス スマホ': ['タブレット'],
#  'デバイス スマホ タブレット': ['pc'],
#  'スマホ タブレット pc': ['アクセス'],
#  'タブレット pc アクセス': ['iphone'],
#  'pc アクセス iphone': ['操作'],
#  'アクセス iphone 操作': ['紛失'],
#  'iphone 操作 紛失': ['モード'],
#  '操作 紛失 モード': ['リモート'],
#  '紛失 モード リモート': ['wipe'],
#  'モード リモート wipe': ['iphone'],
#  'リモート wipe iphone': ['実行'],
#  'wipe iphone 実行': ['mobicontrol'],
#  'iphone 実行 mobicontrol': ['v'],
#  '実行 mobicontrol v': ['端末'],
#  'mobicontrol v 端末': ['登録'],
#  'v 端末 登録': ['adds'],
#  '端末 登録 adds': ['認証'],
#  '登録 adds 認証': ['端末'],
#  '認証 端末 モード': ['監視'],
#  '端末 モード 監視': ['モード'],
#  '監視 モード ad': ['認証'],
#  'モード ad 認証': ['ユーザ'],
#  'ad 認証 ユーザ': ['属性'],
#  '認証 ユーザ 属性': ['把握'],
#  'ユーザ 属性 把握': ['mobicontrol'],
#  '属性 把握 mobicontrol': ['管理'],
#  '把握 mobicontrol 管理': ['領域'],
#  'mobicontrol 管理 領域': ['管理'],
#  '管理 領域 管理': ['領域'],
#  ...}

# %%
#curr_sequence = ' '.join(words_tokens[0:words])
curr_sequence = 'グループ 登録 コンソール'
output = curr_sequence
for i in range(50):
    if curr_sequence not in ngrams.keys():
        break
    possible_words = ngrams[curr_sequence]
    next_word = possible_words[random.randrange(len(possible_words))]
    output += ' ' + next_word
    seq_words = nltk.word_tokenize(output)
    curr_sequence = ' '.join(seq_words[len(seq_words)-words:len(seq_words)])

print(output)
# Out:
# グループ 登録 コンソール

# %%
from collections import Counter
curr_sequence = ' '.join(words_tokens[0:words])
output = curr_sequence
for i in range(50):
    if curr_sequence not in ngrams.keys():
        break
    possible_words = ngrams[curr_sequence]
    top = Counter(possible_words).most_common(1)[0][0]
#     print(top)
#     next_word = possible_words[random.randrange(len(possible_words))]
    output += ' ' + top
    seq_words = nltk.word_tokenize(output)
    curr_sequence = ' '.join(seq_words[len(seq_words)-words:len(seq_words)])
#     break
print(output)
# Out:
# mobicontrol v manual mobicontrol v manual mobicontrol v manual mobicontrol v manual mobicontrol v manual mobicontrol v manual mobicontrol v manual mobicontrol v manual mobicontrol v manual mobicontrol v manual mobicontrol v manual mobicontrol v manual mobicontrol v manual mobicontrol v manual mobicontrol v manual mobicontrol v manual mobicontrol v manual mobicontrol v

# %%
sorted(list(set(k)))
# Out:
# [1, 2, 3, 5]

# %%
k = [1,2,5,3]
