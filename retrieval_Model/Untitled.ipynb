# %%
import pandas as pd
df = pd.read_csv("/home/ifte/amiebot_project/Large_files/mobicontrol_data/Train_Test_Data/japanese/corpus_mobicontrol_tfidf.csv", 
                 header=0, usecols=["page", "text"])

# %%
df.head()
# Out:
#    page                                               text
# 0     0  MobiControlの設定順序 MobiControlの設定順序 MobiControlの...
# 1     1  iOS端末 アクティベーションロック Apple ID とアクティベーションロックの関係 ア...
# 2     2  管理サーバ_証明書等の設定 AD_FSとの接続プロファイル A. AD_FSの必要性 B. ...
# 3     3  端末OS共通の設定項目 端末グループの作成 階層構造で端末グループを作る ルート・グループの...
# 4     4  パッケージ・スタジオ パッケージのアップロード 1. パッケージの管理画面 2. パッケージ...

# %%
        cleaned_corpus_df = df
#         cleaned_corpus_df.to_csv("9.csv", index=False)
        temp_list = cleaned_corpus_df['text'].tolist()
        text_list = []
        for text in temp_list:
            text_list.append(text.split(' '))
        
        flatten = [item for sublist in text_list for item in sublist]
        words = flatten
        wordsunique = set(words)
        wordsunique = list(wordsunique)

# %%
text_list
wordsunique
# Out:
# ['',
#  'テンプレートを選択',
#  'データ収集ルールの内容確認',
#  '1-2.',
#  'パッケージスタジオの起動',
#  'アクセスできるリポジトリ・サーバ',
#  'ウィルススキャンのスケジュール設定',
#  'エージェントソフトのダウンロード元',
#  '端末のMobiControlサーバへの登録の概要',
#  'ジオフェンスのイベントトリガー',
#  '構成プロファイルが適用されているかどうかの確認',
#  '異常状態が発生した場合、管理者にその旨をメール連絡します。同時に、アラート管理画面に、アラートログを表示します。',
#  'フォルダ指定',
#  'ロック画面時間と不正パスコード入力許容回数',
#  'Hubアプリでダウンロードできるファイル形式',
#  '暗号化をするフォルダ/ファイルを指定',
#  'Google',
#  '社内のリポジトリ・サーバから出先でもダウンロード',
#  '4.4.',
#  '端末での仕事用アプリを確認',
#  'AD_FSの必要性',
#  '証明書のテンプレートの配付',
#  'ランチャーの登録',
#  '一覧表への反映',
#  '同期前後に実行するスクリプト',
#  '設定のためのコンソールのタブ',
#  'パッケージの管理画面',
#  'コンテンツ・ライブラリ・ポリシーの内容修正',
#  'iOS端末の操作方法',
#  '受信サーバ',
#  '1.サーバのプロパティの設定',
#  '中央ペインの表示項目の並び順番の変更',
#  'iOSを非監視モードとして登録',
#  'MobiControlサーバを貴社データセンターに設置する場合',
#  '端末の設定とは',
#  '最終トリガー',
#  '設定画面の最初',
#  '過去の軌跡を表示',
#  'DEPトークンのMobiControlサーバへのアップロード',
#  'Android端末のセットアップでの作業項目',
#  'ファイルの同期に関するオプション',
#  'Embedded端末',
#  '隔離フォルダの中を検疫',
#  'アプリカタログ・ルールにアプリを登録',
#  '8-3.',
#  '端末のステータスを知る',
# ...
