# %%
import pandas as pd

# %%
corpus_text = ' '.join(df.Content)

corpus_list = corpus_text.split()

words_list = list(set(corpus_list))

word_ids = list(enumerate(words_list))

word_ids

# %%
input_string = str(df.Content[0]).split()
input_string
# Out:
# ['カスタマイザー',
#  'タイトル',
#  '設定',
#  'カスタマイザー',
#  'サブタイトル',
#  '設定',
#  'MobiControl',
#  '設定',
#  '順序',
#  'MobiControl']

# %%
df.Content[0]
# Out:
# 'カスタマイザー タイトル 設定 カスタマイザー サブタイトル 設定 MobiControl 設定 順序 MobiControl'

# %%
# Vectorizer Just Words -> IDs
def custom_vectorizer(input_list):
    collector = []
    for token in input_list:
        for key, value in word_ids: 
            if value == token:
                # print(value, "->", key)
                collector.append(key)
                break
    return collector

# %%
custom_vectorizer(input_string)
# Out:
# カスタマイザー -> 4758
# タイトル -> 1926
# 設定 -> 1517
# カスタマイザー -> 4758
# サブタイトル -> 4391
# 設定 -> 1517
# MobiControl -> 3126
# 設定 -> 1517
# 順序 -> 3363
# MobiControl -> 3126
# [4758, 1926, 1517, 4758, 4391, 1517, 3126, 1517, 3363, 3126]

# %%
input_vector = list(set(input_string))
#custom_vectorizer(input_string)

# %%
query_vector = custom_vectorizer(input_vector)
query_vector
# Out:
# [4758, 3126, 1926, 3363, 1517, 4391]

# %%
dataset = pd.read_csv('processed_perPage_perLine.csv')
dataset = dataset.iloc[:,1:]
dataset.head()
# Out:
#                                                 Data  PageID
# 0  カスタマイザー タイトル 設定 カスタマイザー サブタイトル 設定 MobiControl ...       0
# 1  Apple 製品 MobiControl v ManualApple 製品 MobiCont...       1
# 2  Android 端末 MobiControl v ManualAndroid 設定 モード ...       2
# 3  Windows PCMobiControl v ManualWindows PC 根本 セキ...       3
# 4  Windows EmbeddedMobiControl v ManualWindows Em...       4

# %%
text_vectors=[]
page_ids = []
for index, col in dataset.iterrows():
    text_vectors.append(custom_vectorizer(str(col['Data']).split()))
    page_ids.append(col['PageID'])

# %%
vector = list(zip(text_vectors, page_ids))

# %%
vector[432]
# Out:
# ([265,
#   4820,
#   824,
#   3656,
#   5276,
#   2351,
#   4820,
#   824,
#   4774,
#   4927,
#   1837,
#   2102,
#   4820,
#   4774,
#   624,
#   6978,
#   3016,
#   2230,
#   3126,
#   3791,
#   6131,
#   265,
#   4820,
#   824,
#   6452,
#   2102,
#   2102,
#   4820,
#   4774,
#   5638,
#   1837,
#   333,
#   2102,
#   4820,
#   4774,
#   2102,
#   4820,
#   4774,
#   333,
#   1453,
#   404,
#   4774,
#   265,
#   4820,
#   4774,
#   4820,
#   2102,
#   765,
#   4820,
#   4774,
#   3595,
#   265,
#   1442,
#   4774,
#   884,
#   1555,
#   3268,
#   624,
#   3016,
#   2230,
#   2102,
#   1295,
#   2334,
#   3110,
#   2422,
#   6767,
#   4820,
#   5056,
#   1376,
#   5350,
#   4847,
#   3268,
#   4820,
#   4774,
#   2422,
#   54,
#   737,
#   4280,
#   3344,
#   265,
#   1442,
#   4774,
#   4927,
#   2247,
#   5646,
#   4774,
#   4616,
#   3227,
#   1514,
#   1453,
#   404,
#   4774,
#   265,
#   4820,
#   4774,
#   4927,
#   1514,
#   1837,
#   2102,
#   4820,
#   4774,
#   2230,
#   2230,
#   1560,
#   4820,
#   4774,
#   5006,
#   624,
#   3016,
#   2230,
#   2230,
#   2230,
#   1560,
#   4820,
#   4774,
#   5638,
#   2102,
#   4820,
#   4774,
#   2230,
#   2230,
#   1560,
#   4820,
#   4774,
#   1453,
#   404,
#   4774,
#   265,
#   4820,
#   4774,
#   2230,
#   1560,
#   3110,
#   4774,
#   4820,
#   4774,
#   5316,
#   265,
#   1442,
#   4774,
#   2230,
#   3126,
#   3791,
#   5926,
#   1956,
#   2230,
#   2440,
#   494,
#   1514,
#   1837,
#   265,
#   1442,
#   4774,
#   5109,
#   2230,
#   4820,
#   4774,
#   265,
#   1442,
#   4774,
#   265,
#   4820,
#   824,
#   6452,
#   2102,
#   5109,
#   624,
#   3016,
#   2230,
#   4820,
#   4774,
#   3126,
#   3791,
#   5926,
#   1956,
#   2230,
#   2440,
#   1956,
#   1837,
#   2102,
#   4820,
#   4774,
#   4537,
#   4820,
#   4774,
#   1274,
#   3178,
#   3935,
#   2102,
#   4820,
#   4774,
#   5273,
#   3178,
#   4820,
#   4774,
#   4045,
#   4537,
#   6224,
#   2247,
#   3948,
#   2995,
#   3178,
#   4820,
#   4774,
#   2995,
#   356,
#   4537,
#   4820,
#   4774,
#   4537,
#   1437,
#   4871,
#   2995,
#   3178,
#   4820,
#   4774,
#   730,
#   4763,
#   356,
#   4537,
#   4155,
#   835,
#   6457,
#   4820,
#   4774,
#   4537,
#   1517,
#   2204,
#   6684,
#   2152,
#   4820,
#   824,
#   4774,
#   4927,
#   3268,
#   2510,
#   6912,
#   3178,
#   4155,
#   3178,
#   265,
#   4820,
#   824,
#   4774,
#   4774,
#   1274,
#   3791,
#   6684,
#   428,
#   3178,
#   4820,
#   4774,
#   2874,
#   1213,
#   6912,
#   4763,
#   4774,
#   4927,
#   3268,
#   2510,
#   6912,
#   3178,
#   4155,
#   3178,
#   4927,
#   4891,
#   4319,
#   6952,
#   879,
#   6758,
#   4891,
#   4319,
#   6952,
#   4891,
#   6889,
#   5124,
#   4134,
#   4820,
#   4774,
#   5028,
#   1956,
#   6032,
#   6558,
#   1392,
#   5451,
#   2220,
#   2874,
#   2510,
#   2874,
#   4774,
#   4820,
#   4774,
#   5028,
#   1956,
#   3178,
#   3935,
#   879,
#   2739,
#   3004,
#   886,
#   879,
#   2739,
#   5393,
#   4725,
#   5843,
#   1437,
#   4280,
#   4430,
#   2874,
#   6196,
#   5028,
#   1956,
#   2874,
#   5065,
#   428,
#   3178,
#   2874,
#   4537,
#   1837,
#   1514,
#   3954,
#   3791,
#   5365,
#   3192,
#   265,
#   1391,
#   4774,
#   1274,
#   3268,
#   2510,
#   4820,
#   4774,
#   265,
#   1442,
#   4774,
#   3791,
#   6330,
#   6646,
#   1952,
#   3126,
#   3791,
#   5323,
#   2230,
#   624,
#   5832,
#   1517,
#   730,
#   624,
#   2230,
#   824,
#   6452,
#   3268,
#   2510,
#   4820,
#   4774,
#   5124,
#   2092,
#   3126,
#   3016,
#   964,
#   5046,
#   6221,
#   832,
#   1471,
#   2230,
#   624,
#   3016,
#   2894,
#   4649,
#   5500,
#   1517,
#   1206,
#   3452,
#   832,
#   3004,
#   5764,
#   2102,
#   566,
#   2204,
#   624,
#   2230,
#   624,
#   3016,
#   2894,
#   4649,
#   5500,
#   3414,
#   2759,
#   6330,
#   696,
#   6092,
#   6684,
#   624,
#   3016,
#   5734,
#   5124,
#   1111,
#   4134,
#   1430,
#   5714,
#   3219,
#   5145,
#   861,
#   5451,
#   5682,
#   4134,
#   5938,
#   735,
#   1179,
#   1517,
#   4215,
#   4134,
#   2108,
#   4134,
#   166,
#   735,
#   1179,
#   1517,
#   5682,
#   5028,
#   1956,
#   624,
#   3016,
#   5734,
#   6540,
#   5257,
#   3154,
#   4823,
#   1006,
#   4941,
#   730,
#   5145,
#   861,
#   5451,
#   2082,
#   6684,
#   4820,
#   2708,
#   3016,
#   3791,
#   166,
#   1213,
#   6196,
#   2729,
#   4820,
#   74,
#   2152,
#   3016,
#   1617,
#   266,
#   5938,
#   2152,
#   3016,
#   4215,
#   631,
#   5938,
#   6626,
#   6196,
#   2729,
#   6758,
#   428,
#   547,
#   2169,
#   5028,
#   3254,
#   5845,
#   2729,
#   4430,
#   2708,
#   3156,
#   2186,
#   3570,
#   730,
#   6457,
#   4367,
#   1617,
#   1295,
#   3412,
#   2708,
#   3791,
#   5116,
#   5727,
#   738,
#   6892,
#   4215,
#   2729,
#   631,
#   1560,
#   3178,
#   4367,
#   6684,
#   4377,
#   1309,
#   2874,
#   730,
#   6558,
#   3178,
#   6513,
#   265,
#   4820,
#   824,
#   652,
#   5451,
#   652,
#   4471,
#   4368,
#   2872,
#   4428,
#   2872,
#   4428,
#   2119,
#   5065,
#   3791,
#   6172,
#   2729,
#   631,
#   4134,
#   5938,
#   6758,
#   3126,
#   1111,
#   4134,
#   3036,
#   926,
#   4820,
#   4530,
#   3791,
#   730,
#   2708,
#   3126,
#   4803,
#   3791,
#   1956,
#   4820,
#   3126,
#   4803,
#   4073,
#   5900,
#   6172,
#   3344,
#   2152,
#   1391,
#   3060,
#   3016,
#   738,
#   4367,
#   730,
#   2708,
#   5028,
#   6684,
#   265,
#   4820,
#   824,
#   6452,
#   3791,
#   1956,
#   2510,
#   2119,
#   1418,
#   4134,
#   50,
#   6032,
#   4820,
#   3791,
#   730,
#   2708,
#   3126,
#   5028,
#   1956,
#   6032,
#   3791,
#   6172,
#   5124,
#   4134,
#   6330,
#   1643,
#   5938,
#   3477,
#   265,
#   4820,
#   824,
#   4774,
#   3791,
#   5788,
#   730,
#   926,
#   2102,
#   1517,
#   6540,
#   5028,
#   1956,
#   4334,
#   5062,
#   4134,
#   624,
#   3016,
#   2230,
#   1915,
#   1324,
#   4215,
#   6250,
#   6760,
#   2102,
#   1517,
#   4215,
#   2427,
#   6330,
#   4134,
#   631,
#   2152,
#   4820,
#   824,
#   4774,
#   2708,
#   5028,
#   1956,
#   2152,
#   4820,
#   824,
#   4774,
#   3178,
#   2667,
#   2119,
#   3134,
#   4322,
#   3126,
#   2102,
#   2152,
#   4820,
#   824,
#   4774,
#   3126,
#   1111,
#   5124,
#   2204,
#   6606,
#   3412,
#   4049,
#   2152,
#   4820,
#   824,
#   4774,
#   3788,
#   5805,
#   5506,
#   6684,
#   1309,
#   5646,
#   730,
#   2708,
#   6357,
#   6340,
#   5638,
#   4155,
#   2708,
#   3788,
#   730,
#   2152,
#   4820,
#   824,
#   4774,
#   2515,
#   2230,
#   1324,
#   2102,
#   138,
#   5123,
#   3149,
#   4134,
#   1811,
#   171,
#   5257,
#   3154,
#   5451,
#   5938,
#   3126,
#   2102,
#   3381,
#   3178,
#   4367,
#   3178,
#   2152,
#   4820,
#   824,
#   4774,
#   4367,
#   4537,
#   4367,
#   4316,
#   1657,
#   4334,
#   5062,
#   960,
#   6196,
#   2729,
#   960,
#   1956,
#   730,
#   3178,
#   4763,
#   7029,
#   1956,
#   798,
#   3126,
#   2102,
#   3381,
#   3178,
#   4763,
#   7029,
#   1956,
#   798,
#   3126,
#   2102,
#   4763,
#   1851,
#   4464,
#   730,
#   4672,
#   3178,
#   2152,
#   4820,
#   824,
#   4774,
#   4820,
#   3791,
#   1956,
#   2335,
#   1418,
#   2152,
#   4820,
#   824,
#   4774,
#   530,
#   1926,
#   5028,
#   1956,
#   960,
#   978,
#   3126,
#   2102,
#   2809,
#   4820,
#   824,
#   4774,
#   2102,
#   1926,
#   5028,
#   1956,
#   5427,
#   6717,
#   4677,
#   6717,
#   4677,
#   4032,
#   5028,
#   266,
#   2152,
#   1391,
#   4215,
#   3791,
#   1274,
#   7041,
#   2230,
#   6023,
#   849,
#   3791,
#   1274,
#   2230,
#   4367,
#   5124,
#   1915,
#   4608,
#   1324,
#   6250,
#   6250,
#   730,
#   1324,
#   3791,
#   2230,
#   4711,
#   2101,
#   4649,
#   5500,
#   2230,
#   2101,
#   4649,
#   5500,
#   1517,
#   1514,
#   2894,
#   4649,
#   5500,
#   2230,
#   2894,
#   4649,
#   5500,
#   1517,
#   1514,
#   1581,
#   624,
#   3016,
#   5114,
#   265,
#   4820,
#   824,
#   6452,
#   2894,
#   4649,
#   5500,
#   4134,
#   5028,
#   1956,
#   265,
#   4820,
#   824,
#   6452,
#   5124,
#   2095,
#   171,
#   2620,
#   730,
#   2911,
#   2101,
#   4649,
#   5500,
#   5028,
#   1956,
#   2911,
#   265,
#   4820,
#   824,
#   6452,
#   5124,
#   4334,
#   5062,
#   265,
#   4820,
#   824,
#   6452,
#   3030,
#   265,
#   4820,
#   824,
#   6452,
#   1324,
#   2102,
#   4820,
#   4774,
#   3288,
#   6250,
#   3201,
#   494,
#   1514,
#   624,
#   2230,
#   1517,
#   3363,
#   4032,
#   3344,
#   4868,
#   884,
#   1309,
#   5646,
#   2528,
#   730,
#   6444,
#   2334,
#   2708,
#   2283,
#   6804,
#   2230,
#   2461,
#   4927,
#   2708,
#   4367,
#   6330,
#   4677,
#   2102,
#   4820,
#   4774,
#   4927,
#   4820,
#   3016,
#   884,
#   265,
#   4820,
#   824,
#   4774,
#   4927,
#   1555,
#   2287,
#   1324,
#   1915,
#   5695,
#   2287,
#   5638,
#   6330,
#   1138,
#   2230,
#   1009,
#   4803,
#   849,
#   1285,
#   4280,
#   6687,
#   6574,
#   5835,
#   1767,
#   4147,
#   3323,
#   4572,
#   4604,
#   2741,
#   6574,
#   3126,
#   5276,
#   3053,
#   64,
#   46,
#   2102,
#   4820,
#   4774,
#   2230,
#   2230,
#   1560,
#   4820,
#   4774,
#   1453,
#   404,
#   4774,
#   265,
#   4820,
#   4774,
#   2230,
#   1560,
#   3110,
#   4774,
#   4820,
#   4774,
#   5316,
#   265,
#   1442,
#   4774,
#   2230,
#   3126,
#   3791,
#   5926,
#   1956,
#   2230,
#   2440,
#   1213,
#   6912,
#   4763,
#   4774,
#   4927,
#   3268,
#   2510,
#   6912,
#   3178,
#   4155,
#   3178,
#   4927,
#   4891,
#   4319,
#   6952,
#   879,
#   6758,
#   4891,
#   4319,
#   6952,
#   4891,
#   6889,
#   5124,
#   4134,
#   4820,
#   4774,
#   5028,
#   1956,
#   6032,
#   6558,
#   1392,
#   5451,
#   2220,
#   2874,
#   2510,
#   2874,
#   4774,
#   4820,
#   4774,
#   5028,
#   1956,
#   3178,
#   3935,
#   879,
#   2739,
#   3004,
#   886,
#   879,
#   2739,
#   5393,
#   ...],
#  432)

# %%
import pickle

# Not writing on disk because already it is present there
# with open('vectormodel_perpage.pkl', 'wb') as f:
#     pickle.dump(vector ,f)
    
with open('vectormodel_perpage.pkl', 'rb') as f:
    vector = pickle.load(f)
    
len(vector)
# Out:
# 445

# %%
len(vector)
# Out:
# 445

# %%
result_collection = []

for words_vector, page_id in vector:    
    result_collection.append([list(set(words_vector).intersection(set(query_vector))),page_id])

# %%
matching_frequency = []
ids_collection = []

for items, ids in result_collection:
    # print(items, ids)
    matching_frequency.append(len(items))
    ids_collection.append(ids)

rank_list = sorted(zip(matching_frequency,ids_collection), reverse=True)[:100]

# %%
collectors = []

cut=0
temp=None

for items, ids in rank_list:
      
    if items!=temp and cut>1:
        break
    elif items==temp: 
        collectors.append([items,ids])
    else:
        cut+=1
        temp = items
        collectors.append([items,ids])
    

collectors
# Out:
# [[6, 0],
#  [4, 432],
#  [4, 396],
#  [4, 262],
#  [4, 236],
#  [4, 188],
#  [4, 177],
#  [4, 157],
#  [4, 148],
#  [4, 112],
#  [4, 105],
#  [4, 53]]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
text_collections=[]
ids_list=[]
for match, ids in collectors:
    text_collections.append(dataset["Data"][ids])
    ids_list.append(ids)

# %%
df.Content[0]
# Out:
# 'カスタマイザー タイトル 設定 カスタマイザー サブタイトル 設定 MobiControl 設定 順序 MobiControl'

# %%
vectorizer = CountVectorizer()
vec = vectorizer.fit(text_collections)
X = vec.transform([df.Content[0]])
# Y = vec.transform(text_collections)

# %%
print(X.shape, Y.shape)
# Out:
# (1, 845) (12, 845)

# %%
rank=[]
for contents in text_collections:
    Y = vec.transform([contents])
    rank.append(cosine_similarity(X, Y))

# %%
flat = [x for sublist in rank for x in sublist]
flat
# Out:
# [array([0.24927601]),
#  array([0.11878423]),
#  array([0.16842845]),
#  array([0.15639158]),
#  array([0.11878423]),
#  array([0.1619498]),
#  array([0.15711807]),
#  array([0.06586649]),
#  array([0.15826582]),
#  array([0.06588078]),
#  array([0.15975747]),
#  array([0.16175206])]

# %%
sorted(zip(flat, ids_list), reverse=True)[:3]
# Out:
# [(array([0.24927601]), 0),
#  (array([0.16842845]), 396),
#  (array([0.1619498]), 188)]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
v = TfidfVectorizer()
v = v.fit(text_collections)

# %%
X = v.transform([df.Content[0]])
rank=[]
for contents in text_collections:
    Y = v.transform([contents])
    rank.append(cosine_similarity(X, Y))
flat = [x for sublist in rank for x in sublist]
sorted(zip(flat, ids_list), reverse=True)[:3]
# Out:
# [(array([0.14288058]), 0),
#  (array([0.08236766]), 396),
#  (array([0.07863517]), 105)]
