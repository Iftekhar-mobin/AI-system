# %%
import networkx as nx
import numpy as np
 
from nltk.tokenize.punkt import PunktSentenceTokenizer
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
 
def textrank(document):
    sentence_tokenizer = PunktSentenceTokenizer()
    sentences = sentence_tokenizer.tokenize(document)
 
    bow_matrix = CountVectorizer().fit_transform(sentences)
    normalized = TfidfTransformer().fit_transform(bow_matrix)
 
    similarity_graph = normalized * normalized.T
 
    nx_graph = nx.from_scipy_sparse_matrix(similarity_graph)
    scores = nx.pagerank(nx_graph)
    return sorted(((scores[i],s) for i,s in enumerate(sentences)),
                  reverse=True)

# %%
file = 'Translated_text_mobicontrol_Page01_JP_to_En.txt'
file = open(file , 'r')
text = file.read()

textrank(text)
# Out:
# [(0.014851742577701553,
#   'to create all "behavior set of terminal" of all of the terminal OS the target document terminal OS is with the exception of distribution and installation Apple products to the target application terminal, image, distributed iOS devices and Android devices to the terminal, such as a video of Section 6.5 subject even if you do not have all of the is completed, the registration of the terminal is possible.'),
#  (0.014851742577701553,
#   'to create all "behavior set of terminal" of all of the terminal OS the target document terminal OS is with the exception of distribution and installation Apple products to the target application terminal, image, distributed iOS devices and Android devices to the terminal, such as a video of Section 6.5 subject even if you do not have all of the is completed, the registration of the terminal is possible.'),
#  (0.013300432537801853,
#   'The one of the company payment terminal (iOS Android), if you shared by a plurality of employees, mandatory\', "2.Apple, Google, or for the purpose of obtaining the following Microsoft administrator for the account of, Apple\'s site the application of managed Google Play to purchase out of the app from the App Store to set out the authority Apple products that you can sign in to the app catalog If you want to distribute using is, it must be one of the two account of the following", \'However, if you want to set your Android device in the mode of Android Plus, the above account is not required.'),
#  (0.013300432537801849,
#   'The one of the company payment terminal (iOS Android), if you shared by a plurality of employees, mandatory\', "2.Apple, Google, or for the purpose of obtaining the following Microsoft administrator for the account of, Apple\'s site the application of managed Google Play to purchase out of the app from the App Store to set out the authority Apple products that you can sign in to the app catalog If you want to distribute using is, it must be one of the two account of the following", \'However, if you want to set your Android device in the mode of Android Plus, the above account is not required.'),
#  (0.012972835958274085,
#   'Overview of registration to the terminal MobiControl server of "registration ID", by the "registration URL" or "Setup.INI" file, the terminal, to know the URL of MobiControl the deployment server, and then the available access.'),
#  (0.012880111989926063,
#   'With respect to the registration of the terminal, click the "setup and operation of the terminal" of the left index, please refer to the page description.'),
#  (0.012880111989926061,
#   'With respect to the registration of the terminal, click the "setup and operation of the terminal" of the left index, please refer to the page description.'),
#  (0.012698134715294048,
#   'Use the WNS, when to remotely manage a Windows10 PC 3. along the organization of companies and organizations, hierarchically (input is the main work of the organization name) the terminal group created all of the terminal OS is subject 4. terminal registration the main purpose of to register the rules of creation terminal to a predetermined terminal group is a terminal registration rules.'),
#  (0.012698134715294046,
#   'Use the WNS, when to remotely manage a Windows10 PC 3. along the organization of companies and organizations, hierarchically (input is the main work of the organization name) the terminal group created all of the terminal OS is subject 4. terminal registration the main purpose of to register the rules of creation terminal to a predetermined terminal group is a terminal registration rules.'),
#  (0.012667466675642239,
#   'Terminal registration rules, the attribute information of the terminal, which has been the access, and save it in the folder of "terminal group" given of MobiControl management server.'),
#  (0.012667466675642235,
#   'Terminal registration rules, the attribute information of the terminal, which has been the access, and save it in the folder of "terminal group" given of MobiControl management server.'),
#  (0.012191046500536505,
#   'Configuration profile of creating information leak prevention, WiFi, VPN, e-mail, such as setting all of the terminal OS is targeting all of the terminal OS of the "Advanced" is other than the target terminal registration rules rules of the (application catalog rules, etc.)'),
#  (0.012191046500536503,
#   'Configuration profile of creating information leak prevention, WiFi, VPN, e-mail, such as setting all of the terminal OS is targeting all of the terminal OS of the "Advanced" is other than the target terminal registration rules rules of the (application catalog rules, etc.)'),
#  (0.01204274933420508,
#   'For one of the terminal groups, it can be set of the plurality of terminal registration rules.'),
#  (0.01204274933420508,
#   'For one of the terminal groups, it can be set of the plurality of terminal registration rules.'),
#  (0.011637148384194218,
#   'Setting order 1 of construction MobiControl in the WordPress.. Creating Required any of the connection profile of the following in the case of all of the terminal OS the target premises MobiControl server if only the setting matters iOS devices or macOS computer required to AD_DS between the (Active Directory Domain Service) server, AD_FS in between the (Active Directory Federation Service), between the Azure AD, essential if you want to manage the Windows10 as Windows Modern.'),
#  (0.01155434505080331,
#   'There is a setting options such as the type of authentication and the terminal name of the terminal user.'),
#  (0.011554345050803307,
#   'There is a setting options such as the type of authentication and the terminal name of the terminal user.'),
#  (0.011348603369629267,
#   'For one of the terminal registration rules, registration destination to become "terminal group" of the terminal is one.'),
#  (0.011348603369629263,
#   'For one of the terminal registration rules, registration destination to become "terminal group" of the terminal is one.'),
#  (0.011344914814529837,
#   'By the "registration ID", "URL for registration" or "Setup.INI" file, the terminal, to know the URL of MobiControl the deployment server, and then the available access.'),
#  (0.01112848150187093,
#   'In addition, depending on the terminal OS, download MobiControl agent software, also by entering the "registration ID" to this, the terminal is registered to a predetermined terminal group.'),
#  (0.011017705434654402,
#   '1.. Creating Required any of the connection profile of the following in the case of all of the terminal OS the target premises MobiControl server if only the setting matters iOS devices or macOS computer required to AD_DS between the (Active Directory Domain Service) server, AD_FS in between the (Active Directory Federation Service), between the Azure AD, essential if you want to manage the Windows10 as Windows Modern.'),
#  (0.010950982226753463,
#   'Gateway for accessing the Intranet inside of the repository server (WebDAV or SharePoint server) from outside\', "To apply his terminal status to iOS devices and Android terminal, the terminal user\'s own, other than the target terminal smartphone, tablet, can be viewed on a PC", \'Such as a terminal to the lost mode, you can remote control.'),
#  (0.010811402253759326,
#   'Without being aware of the intention of as a mobile terminal, the content, it is sufficient to save it to a file server.'),
#  (0.010811402253759319,
#   'Without being aware of the intention of as a mobile terminal, the content, it is sufficient to save it to a file server.'),
#  (0.010777684166591167,
#   'It is to set the field of the terminal there is a "Advanced" and "rules" and "configuration profile".'),
#  (0.010777684166591167,
#   'It is to set the field of the terminal there is a "Advanced" and "rules" and "configuration profile".'),
#  (0.010737451908636689,
#   'All of the terminal OS is the target terminal OS-specific setting method, it will appear menu with the description page by clicking the "Setting" on the left index.'),
#  (0.010737451908636687,
#   'All of the terminal OS is the target terminal OS-specific setting method, it will appear menu with the description page by clicking the "Setting" on the left index.'),
#  (0.010652469068218779, 'All of the terminal OS is subject.'),
#  (0.010652469068218776, 'All of the terminal OS is subject.'),
#  (0.010531784264845006,
#   'In addition, after the registration of the terminal, you can add any of the five terms, it can also be changed.'),
#  (0.010531784264844999,
#   'In addition, after the registration of the terminal, you can add any of the five terms, it can also be changed.'),
#  (0.01040036205031655, 'Setting on the behavior of the terminal.'),
#  (0.01040036205031655, 'Setting on the behavior of the terminal.'),
#  (0.010372092849573718,
#   'When you create a summary terminal registration rules of registration to the terminal MobiControl server, the "registration ID", "URL for registration" will be generated.'),
#  (0.010105223139913107,
#   'By entering the "registration URL" to the browser, the terminal is registered to a predetermined terminal group.'),
#  (0.009920372869798555,
#   'With the intention of as a mobile terminal, the content, it is necessary to upload in advance library.'),
#  (0.009920372869798551,
#   'With the intention of as a mobile terminal, the content, it is necessary to upload in advance library.'),
#  (0.00989963666995012,
#   'Subsequently, the "registration ID", to uniquely corresponding terminal registration rules to the "URL for registration" or "Setup.INI" file, you declare the attribute information, such as its own terminal serial number.'),
#  (0.009899636669950116,
#   'Subsequently, the "registration ID", to uniquely corresponding terminal registration rules to the "URL for registration" or "Setup.INI" file, you declare the attribute information, such as its own terminal serial number.'),
#  (0.00965312256091711,
#   'In the case of iOS, data for which to generate the data or terminal application terminal application is used.'),
#  (0.00965312256091711,
#   'In the case of iOS, data for which to generate the data or terminal application terminal application is used.'),
#  (0.009626224623465816,
#   'Any of which content to download or the terminal user.'),
#  (0.009626224623465815,
#   'Any of which content to download or the terminal user.'),
#  (0.009619452824374014,
#   'When you open the app catalog at the terminal, you will see the name and icon of some of the app.'),
#  (0.009592326625237275,
#   'Delivery of data and content file synchronization rules operation method exchanged between specific folder of the terminal and the server.'),
#  (0.009446877472164585,
#   'In the case of the following If you want to set your Android device if you want to your iOS device, as, it is required to receive the certification of AD_DS or AD_FS.'),
#  (0.009405003010899221,
#   'App catalog MobiControl package published application in-house as long as the app download source in the table on the corporate server iOSAndroid PlusAndroid EnterpriseWindows PCWindows EmbeddedLinux, if the background color is yellow, you can silent installation.'),
#  (0.009363559775981604,
#   'In-house file server (repository server), to download and access from the terminal.'),
#  (0.009363559775981602,
#   'In-house file server (repository server), to download and access from the terminal.'),
#  (0.009293863811876406,
#   'The console authority, is the ability to refer to the terminal user.'),
#  (0.00927865051748881,
#   'As a distribution means of the application, MobiControl is, offers the app catalog and MobiControl package.'),
#  (0.00915077426708335,
#   'There is a need to distribute the business application to distribute mobile terminal or a PC app that does not matter the format of the content.'),
#  (0.00913540461968432,
#   'Data and to the sending mobile device and the PC of content, you need to send the data and content.'),
#  (0.009102259530376574,
#   'Set of option settings following server is not required, and the setting, it spreads the availability of MobiControl.'),
#  (0.009076782501272291,
#   'Format a matter not application of distributed application catalog MobiControl package published application in-house as long as the app download source of the content is set in-house server iOSAndroid PlusAndroid EnterpriseWindows PCWindows EmbeddedLinux options.'),
#  (0.009028395450996136,
#   'In the table below, and the public application, App Store, Google Play Store, or refers to the application of the Windows Store is the download source.'),
#  (0.008891023291237093,
#   'Silent installation on iOS public app, the terminal is monitoring mode, it is when the app is a device type of VPP contract with the App Store.'),
#  (0.008864052251379278,
#   'In addition to public application, developed in-house, you can also distribute the app as long as the house.'),
#  (0.00882187770922204,
#   'File synchronization rules operation method exchanged between specific folder of the terminal and the server.'),
#  (0.008801122342107203, 'Now, registration of the terminal is complete.'),
#  (0.008801122342107202, 'Now, registration of the terminal is complete.'),
#  (0.008776529519563762,
#   'It addressed to Android Enterprise, the application as long as the company, in the managed Google Play Store, it is possible to upload.'),
#  (0.008659496978293747,
#   'Place the Setup.INI file in the same folder as the agent installer, installing the agent, it will be registered in a predetermined terminal group.'),
#  (0.008246182459380254,
#   'For example, you can perform the installation of the previous version of the same app uninstall.'),
#  (0.00822157361603717,
#   'In addition, there is also a desire to obtain an in-house content in the operation of the mobile device side.'),
#  (0.008051917617922715,
#   'In the following cases, you need to initialize the terminal.'),
#  (0.007764838969917437,
#   'The Windows 10PC, as Google administrator account If you want to set as the Windows Modern, if you use the managed Google account (On the other hand, if you use a managed GooglePlay account, the authentication of AD_DS or AD_FS is not required. )'),
#  (0.007666674559900637,
#   'It is automatically transmitted and received on the basis of the schedule.'),
#  (0.0076666745599006355,
#   'It is automatically transmitted and received on the basis of the schedule.'),
#  (0.007610035641657492,
#   'In addition, before and after the installation, you can perform the required operation.'),
#  (0.007607849787355899,
#   'On the terminal screen after the installation is complete, you can display a message to that effect.'),
#  (0.007535187219934629,
#   'In the console, you may want to the generation of agent.'),
#  (0.007280260890277943,
#   'The specification of as a file server, WebDAV or SharePoint.'),
#  (0.007280260890277942,
#   'The specification of as a file server, WebDAV or SharePoint.'),
#  (0.0072739001366705375,
#   'You could even be changing the setting order of the following items.'),
#  (0.007273900136670537,
#   'You could even be changing the setting order of the following items.'),
#  (0.007249341061983402,
#   'In the silent installation, it will be downloaded and installed without terminal user operation.'),
#  (0.007137927676652892,
#   'In this case, you must have the consideration to limit the distribution destination in-house.'),
#  (0.007114451411430366,
#   'Can be specified folder under the umbrella of apps that add-on the iOS as a download destination target AndroidWindows system any folder.'),
#  (0.0071144514114303645,
#   'Can be specified folder under the umbrella of apps that add-on the iOS as a download destination target AndroidWindows system any folder.'),
#  (0.007092946638194517,
#   'Target terminal, iOS terminals, is the Android devices and Windows Embedded terminal.'),
#  (0.007059002534700476, 'This is using the app catalog, and distribute.'),
#  (0.007001453056982076, 'By the terminal OS, how to create different.'),
#  (0.007001453056982074, 'By the terminal OS, how to create different.'),
#  (0.006957314125760786,
#   'Setting order MobiControl of setting order MobiControl of MobiControl is done in the following order:.'),
#  (0.006884573285871031, 'The server is MobiControl server itself.'),
#  (0.006489456009166841,
#   'Terminal users, the download / install Select the app.'),
#  (0.006489358029187341, 'For more information, please refer to the.'),
#  (0.006489358029187341, 'For more information, please refer to the.'),
#  (0.006419566545406299,
#   'Documents, photos, and content such as videos subject.'),
#  (0.006419566545406299,
#   'Documents, photos, and content such as videos subject.'),
#  (0.006419566545406297,
#   'Documents, photos, and content such as videos subject.'),
#  (0.006419566545406297,
#   'Documents, photos, and content such as videos subject.'),
#  (0.006402147346234443,
#   'It is useful for rapid deployment and version-up of the business application.'),
#  (0.006299362992654365,
#   'In addition to the app installer, you can insert a script command.'),
#  (0.006158342315798943,
#   'Silent installation on a Notes application catalog, you must have the application distribution option to "essential".'),
#  (0.006019383553554397,
#   'By default at the OS level, it will be managed MobiControl.'),
#  (0.005856648638383592, 'MobiControl package, using, to package the app.'),
#  (0.005463580755217493,
#   'To prevent illegal access to the MS Exchange server.'),
#  (0.0054206845053983346,
#   'As a result, the application will allow silent installation.'),
#  (0.005164340793893133,
#   'In MobiControl, "File Synchronization Rules", "content library", offers a "intranet gateway".'),
#  (0.004768530153048591,
#   'This time, will also be produced at the same time Setup.INI file.'),
#  (0.004685329071974213, 'You can set this title from customizer.'),
#  (0.004685329071974213, 'You can set this subtitle from customizer.'),
#  (0.00454804322842219,
#   'These include a link to download the original app Yes stretched.'),
#  (0.004398236529896511, 'As reference information, also, please refer.'),
#  (0.0036039535126193645,
#   'Copyright © 2010 -2019 / Translated by Penetrate of Limits Co., Ltd.'),
#  (0.0035002554429457455, '(Tokyo) © 2019 MobiControl v14 Manual.'),
#  (0.001347708894878726, '5.'),
#  (0.001347708894878726, '5.')]

# %%
k = textrank(text)

# %%
k[0][1]
# Out:
# 'to create all "behavior set of terminal" of all of the terminal OS the target document terminal OS is with the exception of distribution and installation Apple products to the target application terminal, image, distributed iOS devices and Android devices to the terminal, such as a video of Section 6.5 subject even if you do not have all of the is completed, the registration of the terminal is possible.'
