# %%
x = 'abc'
if x.find('bc') is not -1:
    print('found')
# Out:
# found

# %%
# Import libraries 
from urllib.request import urljoin 
from bs4 import BeautifulSoup 
import requests 
from urllib.request import urlparse 
  
  
# Set for storing urls with same domain 
links_intern = set() 
input_url = "http://www.inveitco.com/"
depth = 1
  
# Set for storing urls with different domain 
links_extern = set() 
  
  
# Method for crawling a url at next level 
def level_crawler(input_url): 
    temp_urls = set() 
    current_url_domain = urlparse(input_url).netloc 
  
    # Creates beautiful soup object to extract html tags 
    beautiful_soup_object = BeautifulSoup( 
        requests.get(input_url).content, "lxml") 
  
    # Access all anchor tags from input  
    # url page and divide them into internal 
    # and external categories 
    for anchor in beautiful_soup_object.findAll("a"): 
        href = anchor.attrs.get("href") 
        if(href != "" or href != None): 
            href = urljoin(input_url, href) 
            href_parsed = urlparse(href) 
            href = href_parsed.scheme 
            href += "://"
            href += href_parsed.netloc 
            href += href_parsed.path 
            final_parsed_href = urlparse(href) 
            is_valid = bool(final_parsed_href.scheme) and bool( 
                final_parsed_href.netloc) 
            if is_valid: 
                if current_url_domain not in href and href not in links_extern: 
                    print("Extern - {}".format(href)) 
                    links_extern.add(href) 
                if current_url_domain in href and href not in links_intern: 
                    print("Intern - {}".format(href)) 
                    links_intern.add(href) 
                    temp_urls.add(href) 
    return temp_urls 
  
  
if(depth == 0): 
    print("Intern - {}".format(input_url)) 
  
elif(depth == 1): 
    level_crawler(input_url) 
  
else: 
    # We have used a BFS approach 
    # considering the structure as 
    # a tree. It uses a queue based 
    # approach to traverse 
    # links upto a particular depth. 
    queue = [] 
    queue.append(input_url) 
    for j in range(depth): 
        for count in range(len(queue)): 
            url = queue.pop(0) 
            urls = level_crawler(url) 
            for i in urls: 
                queue.append(i)
# Out:
# Extern - http://demo.qodeinteractive.com/elision/clients/
# Extern - http://demo.qodeinteractive.com/elision/blog/masonry/
# Extern - http://demo.qodeinteractive.com/elision/contact/
# Extern - http://demo.qodeinteractive.com/elision/page-leftright-transition/
# Extern - http://demo.qodeinteractive.com/elision/page-fade-updown-transition/
# Extern - http://demo.qodeinteractive.com/elision/page-up-in-fade-out-transition/
# Extern - http://demo.qodeinteractive.com/elision/page-updown-transition/
# Extern - http://demo.qodeinteractive.com/elision/portfolio/gallery-style-condensed/four-columns-grid/
# Extern - http://demo.qodeinteractive.com/elision/portfolio/gallery-style/five-columns-wide-2/
# Extern - http://demo.qodeinteractive.com/elision/portfolio/with-text/three-columns-grid/
# Extern - http://demo.qodeinteractive.com/elision/portfolio/with-text-condensed/four-columns-grid/
# Extern - http://www.facebook.com
# Extern - http://twitter.com
# Extern - http://www.pinterest.com
# Extern - http://www.youtube.com
# Intern - http://www.inveitco.com/
# Intern - http://www.inveitco.com/home/
# Intern - http://www.inveitco.com/about-us/
# Intern - http://www.inveitco.com/services/
# Intern - http://www.inveitco.com/solutions/
# Intern - http://www.inveitco.com/portfolio/
# Intern - http://www.inveitco.com/inveitco-blog/
# Intern - http://www.inveitco.com/contact-us/
# Intern - http://www.inveitco.com/inveitco-wp/solutions/
# Intern - http://www.inveitco.com/inveitco-wp/portfolio/
# Intern - http://www.inveitco.com/inveitco-wp/contact-us/
# Intern - http://www.inveitco.com/wp-content/uploads/2016/12/Teaflakes_1.jpeg
# Intern - http://www.inveitco.com/portfolio_page/ruzzbuk/
# Intern - http://www.inveitco.com/wp-content/uploads/2016/12/22-centramos-1.jpg
# Intern - http://www.inveitco.com/portfolio_page/centramos/
# Intern - http://www.inveitco.com/wp-content/uploads/2016/12/ednius-logo.jpg
# Intern - http://www.inveitco.com/portfolio_page/ednius/
# Intern - http://www.inveitco.com/wp-content/uploads/2016/12/Capture-10.jpg
# Intern - http://www.inveitco.com/portfolio_page/orcaaustralia/
# Intern - http://www.inveitco.com/wp-content/uploads/2019/03/FYPTO.jpeg
# Intern - http://www.inveitco.com/portfolio_page/orcaaustralia-3-2/
# Intern - http://www.inveitco.com/wp-content/uploads/2019/03/Fax-and-Fax-1.jpeg
# Intern - http://www.inveitco.com/portfolio_page/orcaaustralia-2/
# Intern - http://www.inveitco.com/wp-content/uploads/2019/03/Priyo-1-1.jpeg
# Intern - http://www.inveitco.com/portfolio_page/orcaaustralia-3/
# Intern - http://www.inveitco.com/inveitco-wp/services/
# Extern - http://ruzzbuk.com/
# Extern - http://dev.centramos.com
# Extern - http://www.orcaaustralia.org.au
# Extern - mailto://info@inveitco.com
# Extern - https://twitter.com/inveitco
# Extern - https://www.facebook.com/inveitco
# Extern - https://plus.google.com/106128006421132079165
# Intern - http://www.inveitco.com/about-us-2/
# Intern - http://www.inveitco.com/terms-of-use/
# Intern - http://www.inveitco.com/privacy-policy/
# Intern - http://www.inveitco.com/career/

# %%
import urllib.request
from urllib.request import urlretrieve, Request, urlopen
import re

# create a list of all links/href tags 
# url = 'https://www.nttdocomo.co.jp/'
url = 'http://www.inveitco.com/'
urllist = re.findall("href=[\"\'](.*?)[\"\']", urllib.request.urlopen(url).read().decode("utf-8"))

# print each link on a seperate line
i = 1
for elem in urllist:
    print(i, "-", elem)
    i +=1
# Out:
# 1 - http://gmpg.org/xfn/11
# 2 - http://www.inveitco.com/xmlrpc.php
# 3 - http://demo.qodeinteractive.com/elision/wp-content/themes/elision/img/favicon.ico
# 4 - http://demo.qodeinteractive.com/elision/wp-content/themes/elision/img/favicon.ico
# 5 - //fonts.googleapis.com/css?family=Open+Sans:400,800italic,800,700italic,600italic,600,400italic,300italic,300&subset=latin,latin-ext
# 6 - //fonts.googleapis.com
# 7 - //s.w.org
# 8 - http://www.inveitco.com/feed/
# 9 - http://www.inveitco.com/comments/feed/
# 10 - http://www.inveitco.com/home/feed/
# 11 - http://www.inveitco.com/wp-content/plugins/LayerSlider/static/layerslider/css/layerslider.css?ver=6.0.6
# 12 - http://fonts.googleapis.com/css?family=Lato:100,300,regular,700,900%7COpen+Sans:300%7CIndie+Flower:regular%7COswald:300,regular,700&#038;subset=latin%2Clatin-ext
# 13 - http://www.inveitco.com/wp-includes/css/dist/block-library/style.min.css?ver=5.1.1
# 14 - http://www.inveitco.com/wp-content/plugins/js_composer/assets/lib/bower/font-awesome/css/font-awesome.min.css?ver=5.0.1
# 15 - http://www.inveitco.com/wp-content/plugins/contact-form-7/includes/css/styles.css?ver=5.1.1
# 16 - http://www.inveitco.com/wp-content/plugins/live-composer-page-builder/css/font-awesome.css?ver=1.4.2
# 17 - http://www.inveitco.com/wp-content/plugins/live-composer-page-builder/css/frontend/main.css?ver=1.4.2
# 18 - http://www.inveitco.com/wp-content/plugins/live-composer-page-builder/css/frontend/modules.css?ver=1.4.2
# 19 - http://www.inveitco.com/wp-content/plugins/live-composer-page-builder/css/frontend/plugins.css?ver=1.4.2
# 20 - http://www.inveitco.com/wp-content/plugins/live-composer-page-builder/css/ie.css?ver=1.4.2
# 21 - http://www.inveitco.com/wp-content/themes/elision/style.css?ver=5.1.1
# 22 - http://www.inveitco.com/wp-content/themes/elision/css/font-awesome/css/font-awesome.min.css?ver=5.1.1
# 23 - http://www.inveitco.com/wp-content/themes/elision/css/stylesheet.min.css?ver=5.1.1
# 24 - http://www.inveitco.com/wp-content/themes/elision/css/style_dynamic.php?ver=5.1.1
# 25 - http://www.inveitco.com/wp-content/themes/elision/css/responsive.min.css?ver=5.1.1
# 26 - http://www.inveitco.com/wp-content/themes/elision/css/style_dynamic_responsive.php?ver=5.1.1
# 27 - http://www.inveitco.com/wp-content/plugins/js_composer/assets/css/js_composer.min.css?ver=5.0.1
# 28 - http://www.inveitco.com/wp-content/themes/elision/css/custom_css.php?ver=5.1.1
# 29 - http://www.inveitco.com/wp-content/plugins/contact-widgets/assets/css/style.min.css?ver=1.0.1
# 30 - http://www.inveitco.com/wp-json/
# 31 - http://www.inveitco.com/xmlrpc.php?rsd
# 32 - http://www.inveitco.com/wp-includes/wlwmanifest.xml
# 33 - http://www.inveitco.com/
# 34 - http://www.inveitco.com/
# 35 - http://www.inveitco.com/wp-json/oembed/1.0/embed?url=http%3A%2F%2Fwww.inveitco.com%2F
# 36 - http://www.inveitco.com/wp-json/oembed/1.0/embed?url=http%3A%2F%2Fwww.inveitco.com%2F&#038;format=xml
# 37 - http://www.inveitco.com/wp-content/plugins/js_composer/assets/css/vc_lte_ie9.min.css
# 38 - http://www.inveitco.com/wp-content/uploads/2017/01/cropped-Capture-2-32x32.jpg
# 39 - http://www.inveitco.com/wp-content/uploads/2017/01/cropped-Capture-2-192x192.jpg
# 40 - http://www.inveitco.com/wp-content/uploads/2017/01/cropped-Capture-2-180x180.jpg
# 41 - http://demo.qodeinteractive.com/elision/clients/
# 42 - http://demo.qodeinteractive.com/elision/blog/masonry/
# 43 - http://demo.qodeinteractive.com/elision/contact/
# 44 - http://demo.qodeinteractive.com/elision/page-leftright-transition/
# 45 - http://demo.qodeinteractive.com/elision/page-fade-updown-transition/
# 46 - http://demo.qodeinteractive.com/elision/page-up-in-fade-out-transition/
# 47 - http://demo.qodeinteractive.com/elision/page-updown-transition/
# 48 - http://demo.qodeinteractive.com/elision/portfolio/gallery-style-condensed/four-columns-grid/
# 49 - http://demo.qodeinteractive.com/elision/portfolio/gallery-style/five-columns-wide-2/
# 106 - https://plus.google.com/106128006421132079165
# 107 - #
# 108 - http://www.inveitco.com/about-us-2/
# 109 - http://www.inveitco.com/terms-of-use/
# 110 - http://www.inveitco.com/privacy-policy/
# 111 - http://www.inveitco.com/career/

# %%
from bs4 import BeautifulSoup
import urllib.request

# html.parser- built-in - no extra dependencies needed
# html5lib - the most lenient - better use it if HTML is broken
# lxml - the fastest
parser = 'lxml'
resp = urllib.request.urlopen('http://www.inveitco.com/')
soup = BeautifulSoup(resp, parser, from_encoding=resp.info().get_param('charset'))

   
i = 1
for link in soup.find_all('a', href=True):
    print(i, "-", link['href'])
    i +=1
# Out:
# 1 - http://demo.qodeinteractive.com/elision/clients/
# 2 - http://demo.qodeinteractive.com/elision/blog/masonry/
# 3 - http://demo.qodeinteractive.com/elision/contact/
# 4 - http://demo.qodeinteractive.com/elision/page-leftright-transition/
# 5 - http://demo.qodeinteractive.com/elision/page-fade-updown-transition/
# 6 - http://demo.qodeinteractive.com/elision/page-up-in-fade-out-transition/
# 7 - http://demo.qodeinteractive.com/elision/page-updown-transition/
# 8 - http://demo.qodeinteractive.com/elision/portfolio/gallery-style-condensed/four-columns-grid/
# 9 - http://demo.qodeinteractive.com/elision/portfolio/gallery-style/five-columns-wide-2/
# 10 - http://demo.qodeinteractive.com/elision/portfolio/with-text/three-columns-grid/
# 11 - http://demo.qodeinteractive.com/elision/portfolio/with-text-condensed/four-columns-grid/
# 12 - http://www.facebook.com
# 13 - http://twitter.com
# 14 - http://www.pinterest.com
# 15 - http://www.youtube.com
# 16 - http://www.inveitco.com/
# 17 - http://www.inveitco.com/home/
# 18 - http://www.inveitco.com/about-us/
# 19 - http://www.inveitco.com/services/
# 20 - http://www.inveitco.com/solutions/
# 21 - http://www.inveitco.com/portfolio/
# 22 - http://www.inveitco.com/inveitco-blog/
# 23 - http://www.inveitco.com/contact-us/
# 24 - http://www.inveitco.com/home/
# 25 - http://www.inveitco.com/about-us/
# 26 - http://www.inveitco.com/services/
# 27 - http://www.inveitco.com/solutions/
# 28 - http://www.inveitco.com/portfolio/
# 29 - http://www.inveitco.com/inveitco-blog/
# 30 - http://www.inveitco.com/contact-us/
# 31 - #
# 32 - http://www.inveitco.com/services/
# 33 - http://www.inveitco.com/inveitco-wp/solutions/
# 34 - http://www.inveitco.com/inveitco-wp/portfolio/
# 35 - http://www.inveitco.com/inveitco-wp/contact-us/
# 36 - http://www.inveitco.com/inveitco-wp/solutions/
# 37 - http://www.inveitco.com/wp-content/uploads/2016/12/Teaflakes_1.jpeg
# 38 - http://www.inveitco.com/portfolio_page/ruzzbuk/
# 39 - http://www.inveitco.com/portfolio_page/ruzzbuk/
# 40 - http://www.inveitco.com/wp-content/uploads/2016/12/22-centramos-1.jpg
# 41 - http://www.inveitco.com/portfolio_page/centramos/
# 42 - http://www.inveitco.com/portfolio_page/centramos/
# 43 - http://www.inveitco.com/wp-content/uploads/2016/12/ednius-logo.jpg
# 44 - http://www.inveitco.com/portfolio_page/ednius/
# 45 - http://www.inveitco.com/portfolio_page/ednius/
# 46 - http://www.inveitco.com/wp-content/uploads/2016/12/Capture-10.jpg
# 47 - http://www.inveitco.com/portfolio_page/orcaaustralia/
# 48 - http://www.inveitco.com/portfolio_page/orcaaustralia/
# 49 - http://www.inveitco.com/wp-content/uploads/2019/03/FYPTO.jpeg
# 50 - http://www.inveitco.com/portfolio_page/orcaaustralia-3-2/
# 51 - http://www.inveitco.com/portfolio_page/orcaaustralia-3-2/
# 52 - http://www.inveitco.com/wp-content/uploads/2019/03/Fax-and-Fax-1.jpeg
# 53 - http://www.inveitco.com/portfolio_page/orcaaustralia-2/
# 54 - http://www.inveitco.com/portfolio_page/orcaaustralia-2/
# 55 - http://www.inveitco.com/wp-content/uploads/2019/03/Priyo-1-1.jpeg
# 56 - http://www.inveitco.com/portfolio_page/orcaaustralia-3/
# 57 - http://www.inveitco.com/portfolio_page/orcaaustralia-3/
# 58 - http://www.inveitco.com/inveitco-wp/services/
# 59 - http://ruzzbuk.com/
# 60 - http://dev.centramos.com
# 61 - #
# 62 - http://www.orcaaustralia.org.au
# 63 - mailto:info@inveitco.com
# 64 - https://twitter.com/inveitco
# 65 - https://www.facebook.com/inveitco
# 66 - https://plus.google.com/106128006421132079165
# 67 - #
# 68 - http://www.inveitco.com/about-us-2/
# 69 - http://www.inveitco.com/terms-of-use/
# 70 - http://www.inveitco.com/privacy-policy/
# 71 - http://www.inveitco.com/career/

# %%
from bs4 import BeautifulSoup
from bs4.dammit import EncodingDetector
import requests

parser = 'html.parser'  # or 'lxml' (preferred) or 'html5lib', if installed
resp = requests.get(myurl)
http_encoding = resp.encoding if 'charset' in resp.headers.get('content-type', '').lower() else None
html_encoding = EncodingDetector.find_declared_encoding(resp.content, is_html=True)
encoding = html_encoding or http_encoding
soup = BeautifulSoup(resp.content, parser, from_encoding=encoding)

i = 1
for link in soup.find_all('a', href=True):
    print(i, "-", link['href'])
    i +=1
# Out:
# 1 - /iphone/purchase/?icid=CRP_TOP_IPH_purchase
# 2 - https://www.nttdocomo.co.jp/?icid=CRP_common_header_to_CRP_TOP
# 3 - /biz/?icid=CRP_common_header_to_CRP_BIZ_TOP
# 4 - /corporate/?icid=CRP_common_header_to_CRP_CORP
# 5 - /support/shop/?icid=CRP_common_header_to_CRP_SUP_shop
# 6 - /support/inquiry/?icid=CRP_common_header_to_CRP_SUP_inquiry
# 7 - #
# 8 - /support/shop/?icid=CRP_common_header_to_CRP_SUP_shop
# 9 - https://site-search.nttdocomo.co.jp/
# 10 - #
# 11 - /iphone/?icid=CRP_menu_to_CRP_IPH
# 12 - /ipad/?icid=CRP_menu_to_CRP_IPA
# 13 - /apple-watch/?icid=CRP_menu_to_CRP_AW
# 14 - /product/?icid=CRP_menu_to_CRP_PRD
# 15 - /product/smart_phone_5g.html?icid=CRP_menu_to_CRP_PRD_smart_phone_5g
# 16 - /product/smart_phone.html?icid=CRP_menu_to_CRP_PRD_smart_phone
# 17 - /product/tablet.html?icid=CRP_menu_to_CRP_PRD_tablet
# 18 - /product/feature_phone.html?icid=CRP_menu_to_CRP_PRD_feature_phone
# 19 - /charge/?icid=CRP_menu_to_CRP_CHA
# 20 - /charge/discount.html?icid=CRP_menu_to_CRP_CHA_discount
# 21 - /charge/simulation/?icid=CRP_menu_to_CRP_CHA_simulation
# 22 - /service/?icid=CRP_menu_to_CRP_SER
# 23 - /service/anshin_security/?icid=CRP_menu_to_CRP_SER_anshin_security
# 24 - /service/compensation_service/?icid=CRP_menu_to_CRP_SER_compensation_service
# 25 - /service/world/?icid=CRP_menu_to_CRP_SER_world
# 26 - /area/?icid=CRP_menu_to_CRP_AREA
# 27 - /area/servicearea/?rgcd=03&cmcd=LTE&scale=2048000&lat=35.690767&lot=139.756853&icid=CRP_menu_to_CRP_AREA_servicearea
# 28 - /service/d_wifi/?icid=CRP_menu_to_CRP_SER_d_wifi
# 29 - /area/5g/?icid=CRP_menu_to_CRP_AREA_5g
# 30 - /hikari/?icid=CRP_menu_to_CRP_HIKARI
# 31 - /hikari/charge/?icid=CRP_menu_to_CRP_HIKARI_charge
# 32 - /campaign_event/?c=7&icid=CRP_menu_to_CRP_CAM#p02
# 33 - /hikari/application.html?icid=CRP_menu_to_CRP_HIKARI_application
# 34 - /support/shop/?icid=CRP_menu_to_CRP_SUP_shop
# 35 - /support/shop/?icid=CRP_menu_to_CRP_SUP_shop_txt
# 36 - /support/shop/service/reserve_shop/?icid=CRP_menu_to_CRP_SUP_shop_service_reserve_shop
# 37 - /support/shop/service/denwa/?icid=CRP_menu_to_CRP_SUP_shop_service_denwa
# 38 - /service/smart-life/?icid=CRP_menu_to_CRP_SER_smart-life
# 39 - /service/smart-life/?icid=CRP_menu_to_CRP_SER_smart-life_entertainment&tgl_entertainment=1&tgl_life-support=0&tgl_finance=0&tgl_shopping=0&tgl_healthcare=0#entertainment
# 40 - /hikari/docomo_hikaritv/?icid=CRP_menu_to_CRP_HIKARI_docomo_hikaritv
# 41 - /service/dmarket/video_store/?icid=CRP_menu_to_CRP_SER_dmarket_video_store
# 42 - /service/disneyplus/?icid=CRP_menu_to_CRP_SER_disneyplus
# 43 - /service/sugotoku/?icid=CRP_menu_to_CRP_SER_sugotoku
# 44 - /service/dazn/?icid=CRP_menu_to_CRP_SER_dazn
# 45 - /service/ichioshi_pack/?icid=CRP_menu_to_CRP_SER_ichioshi_pack
# 46 - /service/smart-life/?icid=CRP_menu_to_CRP_SER_smart-life_life-support&tgl_entertainment=0&tgl_life-support=1&tgl_finance=0&tgl_shopping=0&tgl_healthcare=0#life-support
# 47 - /utility/daccount/?icid=CRP_menu_to_CRP_UTI_daccount
# 48 - /service/mydaiz/?icid=CRP_menu_to_CRP_SER_mydaiz
# 49 - /service/dmarket/photo/?icid=CRP_menu_to_CRP_SER_dmarket_photo
# 50 - /service/smart-life/?icid=CRP_menu_to_CRP_SER_smart-life_finance&tgl_entertainment=0&tgl_life-support=0&tgl_finance=1&tgl_shopping=0&tgl_healthcare=0#finance
# 51 - /service/id/?icid=CRP_menu_to_CRP_SER_id
# 52 - /service/d_payment/?icid=CRP_menu_to_CRP_SER_d_payment
# 53 - /service/dcard/?icid=CRP_menu_to_CRP_SER_dcard
# 54 - /service/smart-life/?icid=CRP_menu_to_CRP_SER_smart-life_shopping&tgl_entertainment=0&tgl_life-support=0&tgl_finance=0&tgl_shopping=1&tgl_healthcare=0#shopping
# 55 - /service/dmarket/shopping_store/?icid=CRP_menu_to_CRP_SER_dmarket_shopping_store
# 56 - /service/dmarket/travel/?icid=CRP_menu_to_CRP_SER_dmarket_travel
# 57 - /service/dmarket/delivery/?icid=CRP_menu_to_CRP_SER_dmarket_delivery
# 58 - /service/smart-life/?icid=CRP_menu_to_CRP_SER_smart-life_healthcare&tgl_entertainment=0&tgl_life-support=0&tgl_finance=0&tgl_shopping=0&tgl_healthcare=1#healthcare
# 59 - /service/okusuri_link/?icid=CRP_menu_to_CRP_SER_okusuri_link
# 60 - /service/dmarket/healthcare/?icid=CRP_menu_to_CRP_SER_dmarket_healthcare
# 61 - /service/facelog/?icid=CRP_menu_to_CRP_SER_facelog
# 62 - /campaign_event/?icid=CRP_menu_to_CRP_CAM
# 63 - /support/shop/?icid=CRP_menu_to_CRP_SUP_shop
# 64 - /support/shop/search/shop_gps.html?icid=CRP_menu_to_CRP_SUP_shop_search_shop_gps
# 65 - /support/shop/service/reserve_shop/?icid=CRP_menu_to_CRP_SUP_shop_service_reserve_shop
# 66 - /support/?icid=CRP_globalnavi_to_CRP_SUP
# 67 - https://dpoint.jp/ctrw/index.html?utm_source=corp&utm_medium=owned&utm_campaign=dpc_201804_gnav-top
# 68 - /mydocomo/?icid=CRP_globalnavi_to_MYD_TOP
# 69 - https://onlineshop.smt.docomo.ne.jp/index.html?xcid=OLS_TOP_from_CRP_common_header
# 70 - https://www.nttdocomo.co.jp/info/notice/page/200918_00_m.html
# 71 - https://www.nttdocomo.co.jp/info/notice/page/200911_00.html
# 72 - https://www.nttdocomo.co.jp/info/news_release/detail/20200909_00_m.html
# 73 - https://www.nttdocomo.co.jp/info/news_release/2020/12/03_00.html
# 74 - https://www.nttdocomo.co.jp/info/notice/page/200403_03_m.html
# 75 - https://www.nttdocomo.co.jp/support/covid-19.html
# 76 - #
# 77 - #
# 78 - https://www.ahamobile.jp/?=CRP_TOP_mainPR_2020-1203&xcid=CRP_TOP_mainPR_2020-0090_01
# 79 - https://www.nttdocomo.co.jp/special_contents/teacher/gakuwari2021?icid=CRP_TOP_mainPR_2020-0087_02
# 80 - /iphone/?icid=CRP_TOP_mainPR_max_mini_bnr_IPH
# 81 - /iphone/purchase/?icid=CRP_TOP_mainPR_max_mini_IPH_purchase
# 82 - /iphone/12-pro/?icid=CRP_TOP_mainPR_max_mini_IPH_12-pro
# 83 - /iphone/12/?icid=CRP_TOP_mainPR_max_mini_IPH_12
# 84 - https://www.nttdocomo.co.jp/support/promotion/migration/?icid=CRP_TOP_mainPR_2020-0079_04
# 110 - /service/anshin_security/?icid=CRP_TOP_to_CRP_SER_anshin_security
# 111 - /area/?icid=CRP_TOP_to_CRP_AREA
# 112 - /area/servicearea/?rgcd=03&cmcd=LTE&scale=2048000&lat=35.690767&lot=139.756853&icid=CRP_TOP_to_CRP_AREA_servicearea
# 113 - /area/5g/?icid=CRP_TOP_to_CRP_AREA_5g
# 114 - /service/smart-life/?icid=CRP_TOP_to_CRP_SER_smart-life
# 115 - /service/smart-life/?tgl_entertainment=1&tgl_life-support=0&tgl_finance=0&tgl_shopping=0&tgl_healthcare=0&icid=CRP_TOP_to_CRP_SER_smart-life_entertainment#entertainment
# 116 - /service/dazn/?icid=CRP_TOP_to_CRP_SER_dazn
# 117 - /service/disneyplus/?icid=CRP_TOP_to_CRP_SER_disneyplus
# 118 - /hikari/docomo_hikaritv/?icid=CRP_TOP_to_CRP_HIKARI_docomo_hikaritv
# 119 - /service/smart-life/?tgl_entertainment=0&tgl_life-support=1&tgl_finance=0&tgl_shopping=0&tgl_healthcare=0&icid=CRP_TOP_to_CRP_SER_smart-life_life-support#life-support
# 120 - /service/drivers_support/?icid=CRP_TOP_to_CRP_SER_drivers_support
# 121 - /service/kikito/?icid=CRP_TOP_to_CRP_SER_kikito
# 122 - /service/d_wifi/?icid=CRP_TOP_to_CRP_SER_d_wifi
# 123 - /service/smart-life/?tgl_entertainment=0&tgl_life-support=0&tgl_finance=1&tgl_shopping=0&tgl_healthcare=0&icid=CRP_TOP_to_CRP_SER_smart-life_finance#finance
# 124 - /service/d_payment/?icid=CRP_TOP_to_CRP_SER_d_payment
# 125 - /service/id/?icid=CRP_TOP_to_CRP_SER_id
# 126 - /service/dcard/?icid=CRP_TOP_to_CRP_SER_dcard
# 127 - /service/smart-life/?tgl_entertainment=0&tgl_life-support=0&tgl_finance=0&tgl_shopping=1&tgl_healthcare=0&icid=CRP_TOP_to_CRP_SER_smart-life_shopping#shopping
# 128 - /service/smart-life/?tgl_entertainment=0&tgl_life-support=0&tgl_finance=0&tgl_shopping=0&tgl_healthcare=1&icid=CRP_TOP_to_CRP_SER_smart-life_healthcare#healthcare
# 129 - /hikari/?icid=CRP_TOP_to_CRP_HIKARI
# 130 - /hikari/charge/?icid=CRP_TOP_to_CRP_HIKARI_charge
# 131 - /hikari/application.html?icid=CRP_TOP_to_CRP_HIKARI_application
# 132 - /support/?icid=CRP_TOP_to_CRP_SUP
# 133 - /support/procedure.html?icid=CRP_TOP_to_CRP_SUP_procedure
# 134 - /support/lost.html?icid=CRP_TOP_to_CRP_SUP_lost
# 135 - https://dpoint.jp/cp_2/list_201201_1783/index.html?utm_source=corp_info&utm_medium=browserhome&utm_campaign=dpc_202012_1783&utm_content=pc_a
# 136 - /special_contents/teacher/gakuwari2021/?icid=CRP_TOP_to_CRP_SPE_teacher_gakuwari2021
# 137 - /campaign_event/promotion/amazon_prime/?icid=CRP_TOP_to_CRP_CAM_promotion_amazon_prime
# 138 - https://service.smt.docomo.ne.jp/site/special/src/campaign_index.html?utm_source=corp_rec&utm_medium=free-display&utm_campaign=ddx_201912_set
# 139 - https://dpoint.jp/cp_3/d-wifi2_200817/index.html?utm_source=corp&utm_medium=free-display&utm_campaign=dpc_202008_free-dis-dwifi2-camp-09
# 140 - https://service.smt.docomo.ne.jp/keitai_payment/campaign/index.html
# 141 - /campaign_event/5g-welcome_wari/?icid=CRP_TOP_to_CRP_CAM_5g-welcome_wari
# 142 - https://dpoint.jp/cp_2/list_201201_1783/index.html?utm_source=corp_info&utm_medium=browserhome&utm_campaign=dpc_202012_1783&utm_content=pc_a
# 143 - /special_contents/teacher/gakuwari2021/?icid=CRP_TOP_to_CRP_SPE_teacher_gakuwari2021
# 144 - /campaign_event/promotion/amazon_prime/?icid=CRP_TOP_to_CRP_CAM_promotion_amazon_prime
# 145 - https://service.smt.docomo.ne.jp/site/special/src/campaign_index.html?utm_source=corp_rec&utm_medium=free-display&utm_campaign=ddx_201912_set
# 146 - https://dpoint.jp/cp_3/d-wifi2_200817/index.html?utm_source=corp&utm_medium=free-display&utm_campaign=dpc_202008_free-dis-dwifi2-camp-09
# 147 - https://service.smt.docomo.ne.jp/keitai_payment/campaign/index.html
# 148 - /campaign_event/5g-welcome_wari/?icid=CRP_TOP_to_CRP_CAM_5g-welcome_wari
# 149 - /campaign_event/?icid=CRP_TOP_to_CRP_CAM
# 150 - https://www.ntt.co.jp/topics/important/covid19.html
# 151 - /info/rss/
# 152 - /info/notice/page/201228_00.html
# 153 - /info/notice/page/201223_00_m.html
# 154 - /info/notice/page/201217_01_m.html
# 155 - https://www.nttdocomo.co.jp/info/notice/page/190725_01.html
# 156 - /info/notice/page/180725_00_m.html
# 157 - /info/notice/?icid=CRP_TOP_to_CRP_INFO_notice
# 158 - /info/rss/
# 159 - https://www.nttdocomo.co.jp/support/cs_case/index.html
# 160 - https://www.nttdocomo.co.jp/service/sugotoku/index.html
# 161 - https://www.nttdocomo.co.jp/charge/#sec_plan-5g
# 162 - /info/update/?icid=CRP_TOP_to_CRP_INFO_update
# 163 - /info/news_release/?icid=CRP_TOP_to_CRP_INFO_news_release
# 164 - /support/product_update/?icid=CRP_TOP_to_CRP_SUP_product_update
# 165 - /support/product_update/?icid=CRP_TOP_to_CRP_SUP_product_update
# 166 - /info/construction/?icid=CRP_TOP_to_CRP_INFO_construction
# 167 - /info/construction/?icid=CRP_TOP_to_CRP_INFO_construction
# 168 - /info/disaster/?icid=CRP_TOP_to_CRP_INFO_disaster#tab-01-p01
# 169 - /info/disaster/?icid=CRP_TOP_to_CRP_INFO_disaster#p01
# 170 - /corporate/about/?icid=CRP_TOP_to_CRP_CORP_about
# 171 - /corporate/about/?icid=CRP_TOP_to_CRP_CORP_about
# 172 - /corporate/csr/?icid=CRP_TOP_to_CRP_CORP_csr
# 173 - /corporate/csr/?icid=CRP_TOP_to_CRP_CORP_csr
# 174 - /support/cs.html?icid=CRP_TOP_to_CRP_SUP_cs
# 175 - /support/cs.html?icid=CRP_TOP_to_CRP_SUP_cs
# 176 - /corporate/ir/?icid=CRP_TOP_to_CRP_CORP_ir
# 177 - /corporate/ir/?icid=CRP_TOP_to_CRP_CORP_ir
# 178 - /corporate/recruit/?icid=CRP_TOP_to_CRP_CORP_recruit
# 179 - /corporate/recruit/?icid=CRP_TOP_to_CRP_CORP_recruit
# 180 - /corporate/ir/library/announcement/?icid=CRP_TOP_to_CRP_CORP_ir_library_announcement
# 181 - /corporate/ir/library/announcement/?icid=CRP_TOP_to_CRP_CORP_ir_library_announcement
# 182 - #
# 183 - /special_contents/teacher/gakuwari2021/?icid=CRP_TOP_cm_to_CRP_SPE_teacher_gakuwari2021
# 184 - #
# 185 - /support/promotion/migration/?icid=CRP_TOP_cm_to_CRP_SUP_promotion_migration
# 186 - #
# 187 - /special_contents/5g/?icid=CRP_TOP_cm_to_CRP_SPE_5g
# 188 - /special_contents/?icid=CRP_TOP_to_CRP_SPE
# 189 - https://www.facebook.com/docomo.official
# 190 - https://twitter.com/docomo
# 191 - /utility/personal_data/social_media/?icid=CRP_TOP_to_CRP_UTI_personal_data_social_media_line#line
# 192 - https://www.youtube.com/user/docomoOfficial
# 193 - https://www.instagram.com/docomo.official/
# 194 - /utility/personal_data/social_media/?icid=CRP_TOP_to_CRP_UTI_personal_data_social_media
# 195 - /special_contents/5g/?icid=CRP_TOP_to_CRP_SPE_5g
# 196 - /special_contents/beyond2020/tokyo2020/index4_2020.html?icid=CRP_TOP_to_CRP_SPE_beyond2020_tokyo2020_index4_2020
# 197 - /special_contents/disaster/?icid=CRP_TOP_to_CRP_SPE_disaster
# 198 - http://coda-cj.jp/enlightenment/manga.html
# 199 - http://www.npa.go.jp/bureau/safetylife/bohankyoshitsu/2nd/
# 200 - /hokkaido/?icid=CRP_TOP_to_hokkaido
# 201 - /tohoku/?icid=CRP_TOP_to_tohoku
# 202 - /kanto/?icid=CRP_TOP_to_kanto
# 203 - /tokai/?icid=CRP_TOP_to_tokai
# 204 - /hokuriku/?icid=CRP_TOP_to_hokuriku
# 205 - /kansai/?icid=CRP_TOP_to_kansai
# 206 - /chugoku/?icid=CRP_TOP_to_chugoku
# 207 - /shikoku/?icid=CRP_TOP_to_shikoku
# 208 - /kyushu/?icid=CRP_TOP_to_kyushu
# 209 - #
# 210 - /support/chat/
# 211 - #survey
# 212 - #
# 213 - #survey
# 214 - /utility/privacy/?icid=CRP_SURVEY_to_CRP_UTI_privacy
# 215 - /utility/privacy/?icid=CRP_SURVEY_end_to_CRP_UTI_privacy
# 216 - https://www.nttdocomo.co.jp/product/?icid=CRP_common_footer_to_CRP_PRD
# 217 - https://www.nttdocomo.co.jp/product/smart_phone_5g.html?icid=CRP_common_footer_to_CRP_PRD_smart_phone_5g
# 218 - https://www.nttdocomo.co.jp/product/smart_phone.html?icid=CRP_common_footer_to_CRP_PRD_smart_phone
# 219 - https://www.nttdocomo.co.jp/product/tablet.html?icid=CRP_common_footer_to_CRP_PRD_tablet
# 220 - https://www.nttdocomo.co.jp/product/feature_phone.html?icid=CRP_common_footer_to_CRP_PRD_feature_phone
# 221 - https://www.nttdocomo.co.jp/product/easy_phone.html?icid=CRP_common_footer_to_CRP_PRD_easy_phone
# 222 - https://www.nttdocomo.co.jp/product/kids_junior.html?icid=CRP_common_footer_to_CRP_PRD_kids_junior
# 223 - https://www.nttdocomo.co.jp/product/one_number.html?icid=CRP_common_footer_to_CRP_PRD_one_number
# 224 - https://www.nttdocomo.co.jp/product/data.html?icid=CRP_common_footer_to_CRP_PRD_data
# 225 - https://www.nttdocomo.co.jp/product/drivers_support.html?icid=CRP_common_footer_to_CRP_PRD_drivers_support
# 226 - https://www.nttdocomo.co.jp/product/docomo_select.html?icid=CRP_common_footer_to_CRP_PRD_docomo_select
# 227 - https://www.nttdocomo.co.jp/product/xr.html?icid=CRP_common_footer_to_CRP_PRD_xr
# 228 - https://www.nttdocomo.co.jp/charge/?icid=CRP_common_footer_to_CRP_CHA
# 229 - https://www.nttdocomo.co.jp/charge/5g-gigaho/?icid=CRP_common_footer_to_CRP_CHA_5g-gigaho
# 230 - https://www.nttdocomo.co.jp/charge/5g-gigalite/?icid=CRP_common_footer_to_CRP_CHA_5g-gigalite
# 231 - https://www.nttdocomo.co.jp/charge/gigaho-2/?icid=CRP_common_footer_to_CRP_CHA_gigaho-2
# 232 - https://www.nttdocomo.co.jp/charge/gigalite-2/?icid=CRP_common_footer_to_CRP_CHA_gigalite-2
# 233 - https://www.nttdocomo.co.jp/charge/discount.html?icid=CRP_common_footer_to_CRP_CHA_discount
# 234 - https://www.nttdocomo.co.jp/charge/simulation/?icid=CRP_common_footer_to_CRP_CHA_simulation
# 235 - https://www.nttdocomo.co.jp/service/?icid=CRP_common_footer_to_CRP_SER
# 236 - https://www.nttdocomo.co.jp/service/list.html?icid=CRP_common_footer_to_CRP_SER_list
# 237 - https://www.nttdocomo.co.jp/service/dmarket/?icid=CRP_common_footer_to_CRP_SER_dmarket
# 238 - https://www.nttdocomo.co.jp/service/wifi/?icid=CRP_common_footer_to_CRP_SER_wifi
# 239 - https://www.nttdocomo.co.jp/service/world/?icid=CRP_common_footer_to_CRP_SER_world
# 240 - https://www.nttdocomo.co.jp/area/?icid=CRP_common_footer_to_CRP_AREA
# 241 - https://www.nttdocomo.co.jp/area/service_area.html?icid=CRP_common_footer_to_CRP_AREA_service_area
# 242 - https://www.nttdocomo.co.jp/area/reception.html?icid=CRP_common_footer_to_CRP_AREA_reception
# 243 - https://www.nttdocomo.co.jp/area/effort.html?icid=CRP_common_footer_to_CRP_AREA_effort
# 244 - https://www.nttdocomo.co.jp/area/connect.html?icid=CRP_common_footer_to_CRP_AREA_connect
# 245 - https://www.nttdocomo.co.jp/area/technology.html?icid=CRP_common_footer_to_CRP_AREA_technology
# 246 - https://www.nttdocomo.co.jp/support/?icid=CRP_common_footer_to_CRP_SUP
# 247 - https://www.nttdocomo.co.jp/support/apple.html?icid=CRP_common_footer_to_CRP_SUP_apple
# 248 - https://www.nttdocomo.co.jp/support/product.html?icid=CRP_common_footer_to_CRP_SUP_product
# 273 - https://www.nttdocomo.co.jp/service/smart-life/?icid=CRP_common_footer_to_CRP_SER_smart-life_healthcare&tgl_entertainment=0&tgl_life-support=0&tgl_finance=0&tgl_shopping=0&tgl_healthcare=1#healthcare
# 274 - https://www.nttdocomo.co.jp/hikari/?icid=CRP_common_footer_to_CRP_HIKARI
# 275 - https://www.nttdocomo.co.jp/hikari/charge/?icid=CRP_common_footer_to_CRP_HIKARI_charge
# 276 - https://www.nttdocomo.co.jp/hikari/beginner/?icid=CRP_common_footer_to_CRP_HIKARI_beginner
# 277 - https://www.nttdocomo.co.jp/hikari/tell_service/?icid=CRP_common_footer_to_CRP_HIKARI_tell_service
# 278 - https://www.nttdocomo.co.jp/hikari/eizo_service.html?icid=CRP_common_footer_to_CRP_HIKARI_eizo_service
# 279 - https://www.nttdocomo.co.jp/hikari/support/?icid=CRP_common_footer_to_CRP_HIKARI_support
# 280 - https://www.nttdocomo.co.jp/mydocomo/?icid=CRP_common_footer_to_CRP_MYD
# 281 - https://www.nttdocomo.co.jp/mydocomo/data/?icid=CRP_common_footer_to_CRP_MYD_data
# 282 - https://www.nttdocomo.co.jp/mydocomo/payment/?icid=CRP_common_footer_to_CRP_MYD_payment
# 283 - https://www.nttdocomo.co.jp/mydocomo/procedures/?icid=CRP_common_footer_to_CRP_MYD_procedures
# 284 - https://www.nttdocomo.co.jp/mydocomo/settings/?icid=CRP_common_footer_to_CRP_MYD_settings
# 285 - https://www.nttdocomo.co.jp/mydocomo/point/?icid=CRP_common_footer_to_CRP_MYD_point
# 286 - https://www.nttdocomo.co.jp/mydocomo/support/?icid=CRP_common_footer_to_CRP_MYD_support
# 287 - https://onlineshop.smt.docomo.ne.jp/index.html?xcid=OLS_TOP_from_CRP_common_footer
# 288 - https://www.nttdocomo.co.jp/campaign_event/?icid=CRP_common_footer_to_CRP_CAM
# 289 - https://www.nttdocomo.co.jp/utility/daccount/?icid=CRP_common_footer_to_CRP_UTI_daccount
# 290 - https://www.nttdocomo.co.jp/support/shop/?icid=CRP_common_footer_to_CRP_SUP_shop
# 291 - https://www.nttdocomo.co.jp/info/?icid=CRP_common_footer_to_CRP_INFO
# 292 - https://faq.nttdocomo.co.jp/faq/
# 293 - https://faq.nttdocomo.co.jp/faq/s/
# 294 - https://www.nttdocomo.co.jp/english/?icid=CRP_common_footer_to_CRP_EN
# 295 - https://www.nttdocomo.co.jp/utility/personal_data/?icid=CRP_common_footer_to_CRP_UTI_personal_data
# 296 - https://www.nttdocomo.co.jp/utility/privacy/?icid=CRP_common_footer_to_CRP_UTI_privacy
# 297 - https://www.nttdocomo.co.jp/utility/term/?icid=CRP_common_footer_to_CRP_UTI_term
# 298 - https://www.nttdocomo.co.jp/support/feedback.html?icid=CRP_common_footer_to_CRP_SUP_feedback
# 299 - https://www.nttdocomo.co.jp/mydocomo/maint/?icid=CRP_common_footer_to_CRP_MYD_maint
# 300 - https://www.nttdocomo.co.jp/sitemap/?icid=CRP_common_footer_to_CRP_sitemap
# 301 - https://faq.nttdocomo.co.jp/faq/s/
# 302 - /support/inquiry/?icid=CRP_drawer_to_CRP_SUP_inquiry
# 303 - /info/?icid=CRP_drawer_to_CRP_INF
# 304 - /corporate/?icid=CRP_drawer_to_CRP_CORP
# 305 - /biz/?icid=CRP_common_header_to_CRP_BIZ_TOP

# %%
url_re

# %%
myurl = "https://www.nttdocomo.co.jp/"

# %%
# Python 3.
import urllib    
from bs4 import BeautifulSoup

url = "http://www.espncricinfo.com/"
resp = urllib.request.urlopen(url)
# Get server encoding per recommendation of Martijn Pieters.
soup = BeautifulSoup(resp, from_encoding=resp.info().get_param('charset'))  
external_links = set()
internal_links = set()
for line in soup.find_all('a'):
    link = line.get('href')
    if not link:
        continue
    if link.startswith('http'):
        external_links.add(link)
    else:
        internal_links.add(link)

# Depending on usage, full internal links may be preferred.
full_internal_links = {
    urllib.parse.urljoin(url, internal_link) 
    for internal_link in internal_links
}

# Print all unique external and full internal links.
i = 1
for link in external_links.union(full_internal_links):
    print(i, "-" ,link)
    i +=1
# Out:
# 1 - https://www.instagram.com/espncricinfo/
# 2 - https://www.thecricketmonthly.com/story/1226516/the-many-shades-of-marlon-samuels
# 3 - https://play.google.com/store/apps/details?id=com.july.cricinfo&hl=en
# 4 - http://www.espncricinfo.com/ci/content/video_audio/index.html?genre=1
# 5 - https://www.thecricketmonthly.com/story/1243309/how-mitchell-starc-went-from-f-you-to-i-can-t-hear-you
# 6 - http://www.espncricinfo.com/series/world-cup-league-2-2019-2021-22-1196667
# 7 - https://www.espncricinfo.com/ci/content/story/149480.html
# 8 - https://www.espncricinfo.com/ci/content/story/features.html
# 9 - http://www.espncricinfo.com/series/quaid-e-azam-second-xi-2020-21-1231308/match-schedule-fixtures
# 10 - https://submit.espncricinfo.com/ci/content/submit/forms/feedback.html
# 11 - https://www.espncricinfo.com/wisdenalmanack/content/story/almanack
# 12 - http://www.espncricinfo.com/team/united-states-of-america-11
# 13 - https://www.thecricketmonthly.com/
# 14 - http://www.espncricinfo.com/ci/content/video_audio/index.html?genre=34
# 15 - https://www.espncricinfo.com/table/series/19430/season/2019/icc-world-test-championship
# 16 - http://www.espncricinfo.com/ci/content/video_audio/index.html?genre=85
# 17 - http://www.espncricinfo.com/story/sixers-v-renegades-bbl-2020-21-josh-philippe-shines-with-95-before-melbourne-renegades-embarrassing-collapse-1243740
# 18 - https://www.thecricketmonthly.com/story/1229170/when-vvs-laxman-turned-out-to-bat-for-pudsey-congs
# 19 - http://www.espncricinfo.com/team/afghanistan-40
# 20 - https://www.espncricinfo.com/ci/engine/match/scores/desktop.html
# 21 - http://www.espncricinfo.com/series/lanka-premier-league-2020-21-1237339/dambulla-viiking-vs-jaffna-stallions-2nd-semi-final-1238773/live-cricket-score
# 22 - http://www.espncricinfo.com/team/united-arab-emirates-27
# 23 - http://www.espncricinfo.com/team/papua-new-guinea-20
# 135 - http://www.espncricinfo.com/series/west-indies-in-nz-2020-21-1233943
# 136 - http://www.espncricinfo.com/series/big-bash-league-2020-21-1226769
# 137 - http://www.espncricinfo.com/team/ireland-29
# 138 - http://www.espncricinfo.com/story/nz-vs-wi-2nd-test-if-players-can-travel-and-quarantine-why-can-t-umpires-jason-holder-1243802
# 139 - http://www.espncricinfo.com/story/nz-vs-wi-no-rush-to-get-back-to-lord-s-but-trent-boult-tempted-by-test-championship-final-1243720
# 140 - http://www.espncricinfo.com/story/pakistan-vs-new-zealand-babar-azam-ruled-out-of-t20is-against-new-zealand-1243702
# 141 - http://www.espncricinfo.com/ci/content/video_audio/index.html?genre=9
# 142 - http://www.espncricinfo.com/series/big-bash-league-2020-21-1226769/sydney-thunder-vs-brisbane-heat-7th-match-1226866/live-cricket-score
# 143 - http://www.espncricinfo.com/team/scotland-30
# 144 - http://www.espncricinfo.com/series/lanka-premier-league-2020-21-1237339
# 145 - http://www.espncricinfo.com/story/aus-vs-ind-2020-21-mitchell-starc-boots-made-to-have-nathan-lyon-victims-walking-1243779
# 146 - http://www.espncricinfo.com/series/icc-women-s-championship-2017-18-2021-1122932
# 147 - http://www.espncricinfo.com/series/the-ford-trophy-2020-21-1234905
# 148 - https://twitter.com/espncricinfo

# %%
import urllib
import lxml.html
connection = urllib.request.urlopen("https://www.nttdocomo.co.jp/")

dom =  lxml.html.fromstring(connection.read())
i = 1
for link in dom.xpath('//a/@href'): # select the url in href for all a tags(links)
    print(i, "-" ,link)
    i +=1
# Out:
# 1 - /iphone/purchase/?icid=CRP_TOP_IPH_purchase
# 2 - https://www.nttdocomo.co.jp/?icid=CRP_common_header_to_CRP_TOP
# 3 - /biz/?icid=CRP_common_header_to_CRP_BIZ_TOP
# 4 - /corporate/?icid=CRP_common_header_to_CRP_CORP
# 5 - /support/shop/?icid=CRP_common_header_to_CRP_SUP_shop
# 6 - /support/inquiry/?icid=CRP_common_header_to_CRP_SUP_inquiry
# 7 - #
# 8 - /support/shop/?icid=CRP_common_header_to_CRP_SUP_shop
# 9 - https://site-search.nttdocomo.co.jp/
# 10 - #
# 11 - /iphone/?icid=CRP_menu_to_CRP_IPH
# 12 - /ipad/?icid=CRP_menu_to_CRP_IPA
# 13 - /apple-watch/?icid=CRP_menu_to_CRP_AW
# 14 - /product/?icid=CRP_menu_to_CRP_PRD
# 15 - /product/smart_phone_5g.html?icid=CRP_menu_to_CRP_PRD_smart_phone_5g
# 16 - /product/smart_phone.html?icid=CRP_menu_to_CRP_PRD_smart_phone
# 17 - /product/tablet.html?icid=CRP_menu_to_CRP_PRD_tablet
# 18 - /product/feature_phone.html?icid=CRP_menu_to_CRP_PRD_feature_phone
# 19 - /charge/?icid=CRP_menu_to_CRP_CHA
# 20 - /charge/discount.html?icid=CRP_menu_to_CRP_CHA_discount
# 21 - /charge/simulation/?icid=CRP_menu_to_CRP_CHA_simulation
# 22 - /service/?icid=CRP_menu_to_CRP_SER
# 23 - /service/anshin_security/?icid=CRP_menu_to_CRP_SER_anshin_security
# 24 - /service/compensation_service/?icid=CRP_menu_to_CRP_SER_compensation_service
# 25 - /service/world/?icid=CRP_menu_to_CRP_SER_world
# 26 - /area/?icid=CRP_menu_to_CRP_AREA
# 27 - /area/servicearea/?rgcd=03&cmcd=LTE&scale=2048000&lat=35.690767&lot=139.756853&icid=CRP_menu_to_CRP_AREA_servicearea
# 28 - /service/d_wifi/?icid=CRP_menu_to_CRP_SER_d_wifi
# 29 - /area/5g/?icid=CRP_menu_to_CRP_AREA_5g
# 30 - /hikari/?icid=CRP_menu_to_CRP_HIKARI
# 31 - /hikari/charge/?icid=CRP_menu_to_CRP_HIKARI_charge
# 32 - /campaign_event/?c=7&icid=CRP_menu_to_CRP_CAM#p02
# 33 - /hikari/application.html?icid=CRP_menu_to_CRP_HIKARI_application
# 34 - /support/shop/?icid=CRP_menu_to_CRP_SUP_shop
# 35 - /support/shop/?icid=CRP_menu_to_CRP_SUP_shop_txt
# 36 - /support/shop/service/reserve_shop/?icid=CRP_menu_to_CRP_SUP_shop_service_reserve_shop
# 37 - /support/shop/service/denwa/?icid=CRP_menu_to_CRP_SUP_shop_service_denwa
# 38 - /service/smart-life/?icid=CRP_menu_to_CRP_SER_smart-life
# 39 - /service/smart-life/?icid=CRP_menu_to_CRP_SER_smart-life_entertainment&tgl_entertainment=1&tgl_life-support=0&tgl_finance=0&tgl_shopping=0&tgl_healthcare=0#entertainment
# 40 - /hikari/docomo_hikaritv/?icid=CRP_menu_to_CRP_HIKARI_docomo_hikaritv
# 41 - /service/dmarket/video_store/?icid=CRP_menu_to_CRP_SER_dmarket_video_store
# 42 - /service/disneyplus/?icid=CRP_menu_to_CRP_SER_disneyplus
# 43 - /service/sugotoku/?icid=CRP_menu_to_CRP_SER_sugotoku
# 44 - /service/dazn/?icid=CRP_menu_to_CRP_SER_dazn
# 45 - /service/ichioshi_pack/?icid=CRP_menu_to_CRP_SER_ichioshi_pack
# 46 - /service/smart-life/?icid=CRP_menu_to_CRP_SER_smart-life_life-support&tgl_entertainment=0&tgl_life-support=1&tgl_finance=0&tgl_shopping=0&tgl_healthcare=0#life-support
# 47 - /utility/daccount/?icid=CRP_menu_to_CRP_UTI_daccount
# 48 - /service/mydaiz/?icid=CRP_menu_to_CRP_SER_mydaiz
# 49 - /service/dmarket/photo/?icid=CRP_menu_to_CRP_SER_dmarket_photo
# 50 - /service/smart-life/?icid=CRP_menu_to_CRP_SER_smart-life_finance&tgl_entertainment=0&tgl_life-support=0&tgl_finance=1&tgl_shopping=0&tgl_healthcare=0#finance
# 51 - /service/id/?icid=CRP_menu_to_CRP_SER_id
# 52 - /service/d_payment/?icid=CRP_menu_to_CRP_SER_d_payment
# 53 - /service/dcard/?icid=CRP_menu_to_CRP_SER_dcard
# 54 - /service/smart-life/?icid=CRP_menu_to_CRP_SER_smart-life_shopping&tgl_entertainment=0&tgl_life-support=0&tgl_finance=0&tgl_shopping=1&tgl_healthcare=0#shopping
# 55 - /service/dmarket/shopping_store/?icid=CRP_menu_to_CRP_SER_dmarket_shopping_store
# 56 - /service/dmarket/travel/?icid=CRP_menu_to_CRP_SER_dmarket_travel
# 57 - /service/dmarket/delivery/?icid=CRP_menu_to_CRP_SER_dmarket_delivery
# 58 - /service/smart-life/?icid=CRP_menu_to_CRP_SER_smart-life_healthcare&tgl_entertainment=0&tgl_life-support=0&tgl_finance=0&tgl_shopping=0&tgl_healthcare=1#healthcare
# 59 - /service/okusuri_link/?icid=CRP_menu_to_CRP_SER_okusuri_link
# 60 - /service/dmarket/healthcare/?icid=CRP_menu_to_CRP_SER_dmarket_healthcare
# 61 - /service/facelog/?icid=CRP_menu_to_CRP_SER_facelog
# 62 - /campaign_event/?icid=CRP_menu_to_CRP_CAM
# 63 - /support/shop/?icid=CRP_menu_to_CRP_SUP_shop
# 64 - /support/shop/search/shop_gps.html?icid=CRP_menu_to_CRP_SUP_shop_search_shop_gps
# 65 - /support/shop/service/reserve_shop/?icid=CRP_menu_to_CRP_SUP_shop_service_reserve_shop
# 66 - /support/?icid=CRP_globalnavi_to_CRP_SUP
# 67 - https://dpoint.jp/ctrw/index.html?utm_source=corp&utm_medium=owned&utm_campaign=dpc_201804_gnav-top
# 68 - /mydocomo/?icid=CRP_globalnavi_to_MYD_TOP
# 69 - https://onlineshop.smt.docomo.ne.jp/index.html?xcid=OLS_TOP_from_CRP_common_header
# 70 - https://www.nttdocomo.co.jp/info/notice/page/200918_00_m.html
# 71 - https://www.nttdocomo.co.jp/info/notice/page/200911_00.html
# 72 - https://www.nttdocomo.co.jp/info/news_release/detail/20200909_00_m.html
# 73 - https://www.nttdocomo.co.jp/info/news_release/2020/12/03_00.html
# 74 - https://www.nttdocomo.co.jp/info/notice/page/200403_03_m.html
# 75 - https://www.nttdocomo.co.jp/support/covid-19.html
# 76 - #
# 77 - #
# 78 - https://www.ahamobile.jp/?=CRP_TOP_mainPR_2020-1203&xcid=CRP_TOP_mainPR_2020-0090_01
# 79 - https://www.nttdocomo.co.jp/special_contents/teacher/gakuwari2021?icid=CRP_TOP_mainPR_2020-0087_02
# 80 - /iphone/?icid=CRP_TOP_mainPR_max_mini_bnr_IPH
# 81 - /iphone/purchase/?icid=CRP_TOP_mainPR_max_mini_IPH_purchase
# 82 - /iphone/12-pro/?icid=CRP_TOP_mainPR_max_mini_IPH_12-pro
# 83 - /iphone/12/?icid=CRP_TOP_mainPR_max_mini_IPH_12
# 84 - https://www.nttdocomo.co.jp/support/promotion/migration/?icid=CRP_TOP_mainPR_2020-0079_04
# 85 - https://book.dmkt-sp.jp/sp/20201221dcm23vdfael/20201221dcm23vdfael.html?utm_source=corp_top&utm_medium=free-display&utm_campaign=dbook_202012_CP01&xcid=CRP_TOP_mainPR_2020-0088_05
# 86 - https://dpoint.jp/cp_2/list_201201_1783/index.html?utm_source=corp_top&utm_medium=browserhome&utm_campaign=dpc_202012_1783&utm_content=pc_a&xcid=CRP_TOP_mainPR_2020-0086_06
# 87 - https://www.nttdocomo.co.jp/product/promotion/20-21_docomo_collection/?icid=CRP_TOP_mainPR_2020-0082_07
# 88 - https://onlineshop.smt.docomo.ne.jp/index.html?xcid=OLS_TOP_from_CRP_TOP_mainPR_bnr_201122&xcid=CRP_TOP_mainPR_2020-0085_08
# 89 - https://www.ahamobile.jp/?=CRP_TOP_mainPR_2020-1203&xcid=CRP_TOP_mainPR_2020-0090_01
# 90 - https://www.nttdocomo.co.jp/special_contents/teacher/gakuwari2021?icid=CRP_TOP_mainPR_2020-0087_02
# 91 - /iphone/?icid=CRP_TOP_mainPR_max_mini_IPH_js_off
# 92 - https://www.nttdocomo.co.jp/support/promotion/migration/?icid=CRP_TOP_mainPR_2020-0079_04
# 93 - https://book.dmkt-sp.jp/sp/20201221dcm23vdfael/20201221dcm23vdfael.html?utm_source=corp_top&utm_medium=free-display&utm_campaign=dbook_202012_CP01&xcid=CRP_TOP_mainPR_2020-0088_05
# 94 - https://dpoint.jp/cp_2/list_201201_1783/index.html?utm_source=corp_top&utm_medium=browserhome&utm_campaign=dpc_202012_1783&utm_content=pc_a&xcid=CRP_TOP_mainPR_2020-0086_06
# 95 - https://www.nttdocomo.co.jp/product/promotion/20-21_docomo_collection/?icid=CRP_TOP_mainPR_2020-0082_07
# 96 - https://onlineshop.smt.docomo.ne.jp/index.html?xcid=OLS_TOP_from_CRP_TOP_mainPR_bnr_201122&xcid=CRP_TOP_mainPR_2020-0085_08
# 97 - https://www.nttdocomo.co.jp/info/notice/page/201106_00.html
# 98 - https://www.nttdocomo.co.jp/info/news_release/2020/10/16_00.html
# 99 - https://www.nttdocomo.co.jp/info/notice/page/201016_00.html
# 100 - /product/?icid=CRP_TOP_to_CRP_PRD
# 101 - /product/promotion/20-21_docomo_collection/?icid=CRP_TOP_to_CRP_PRD_promotion_20-21_docomo_collection
# 102 - /product/smart_phone_5g.html?icid=CRP_TOP_to_CRP_PRD_smart_phone_5g
# 103 - /iphone/?icid=CRP_TOP_to_CRP_IPH
# 104 - /charge/?icid=CRP_TOP_to_CRP_CHA
# 105 - /charge/promotion/5g-gigaho_5g-gigalite/?icid=CRP_TOP_to_CRP_CHA_promotion_5g-gigaho_5g-gigalite
# 106 - /charge/promotion/gigaho_gigalite/?icid=CRP_TOP_to_CRP_CHA_promotion_gigaho_gigalite
# 107 - /charge/simulation/?icid=CRP_TOP_to_CRP_CHA_simulation
# 108 - /service/?icid=CRP_TOP_to_CRP_SER
# 109 - /service/compensation_service/?icid=CRP_TOP_to_CRP_SER_compensation_service
# 110 - /service/anshin_security/?icid=CRP_TOP_to_CRP_SER_anshin_security
# 111 - /area/?icid=CRP_TOP_to_CRP_AREA
# 112 - /area/servicearea/?rgcd=03&cmcd=LTE&scale=2048000&lat=35.690767&lot=139.756853&icid=CRP_TOP_to_CRP_AREA_servicearea
# 113 - /area/5g/?icid=CRP_TOP_to_CRP_AREA_5g
# 114 - /service/smart-life/?icid=CRP_TOP_to_CRP_SER_smart-life
# 115 - /service/smart-life/?tgl_entertainment=1&tgl_life-support=0&tgl_finance=0&tgl_shopping=0&tgl_healthcare=0&icid=CRP_TOP_to_CRP_SER_smart-life_entertainment#entertainment
# 116 - /service/dazn/?icid=CRP_TOP_to_CRP_SER_dazn
# 117 - /service/disneyplus/?icid=CRP_TOP_to_CRP_SER_disneyplus
# 118 - /hikari/docomo_hikaritv/?icid=CRP_TOP_to_CRP_HIKARI_docomo_hikaritv
# 119 - /service/smart-life/?tgl_entertainment=0&tgl_life-support=1&tgl_finance=0&tgl_shopping=0&tgl_healthcare=0&icid=CRP_TOP_to_CRP_SER_smart-life_life-support#life-support
# 120 - /service/drivers_support/?icid=CRP_TOP_to_CRP_SER_drivers_support
# 121 - /service/kikito/?icid=CRP_TOP_to_CRP_SER_kikito
# 122 - /service/d_wifi/?icid=CRP_TOP_to_CRP_SER_d_wifi
# 123 - /service/smart-life/?tgl_entertainment=0&tgl_life-support=0&tgl_finance=1&tgl_shopping=0&tgl_healthcare=0&icid=CRP_TOP_to_CRP_SER_smart-life_finance#finance
# 124 - /service/d_payment/?icid=CRP_TOP_to_CRP_SER_d_payment
# 125 - /service/id/?icid=CRP_TOP_to_CRP_SER_id
# 126 - /service/dcard/?icid=CRP_TOP_to_CRP_SER_dcard
# 127 - /service/smart-life/?tgl_entertainment=0&tgl_life-support=0&tgl_finance=0&tgl_shopping=1&tgl_healthcare=0&icid=CRP_TOP_to_CRP_SER_smart-life_shopping#shopping
# 128 - /service/smart-life/?tgl_entertainment=0&tgl_life-support=0&tgl_finance=0&tgl_shopping=0&tgl_healthcare=1&icid=CRP_TOP_to_CRP_SER_smart-life_healthcare#healthcare
# 129 - /hikari/?icid=CRP_TOP_to_CRP_HIKARI
# 130 - /hikari/charge/?icid=CRP_TOP_to_CRP_HIKARI_charge
# 131 - /hikari/application.html?icid=CRP_TOP_to_CRP_HIKARI_application
# 132 - /support/?icid=CRP_TOP_to_CRP_SUP
# 133 - /support/procedure.html?icid=CRP_TOP_to_CRP_SUP_procedure
# 134 - /support/lost.html?icid=CRP_TOP_to_CRP_SUP_lost
# 135 - https://dpoint.jp/cp_2/list_201201_1783/index.html?utm_source=corp_info&utm_medium=browserhome&utm_campaign=dpc_202012_1783&utm_content=pc_a
# 136 - /special_contents/teacher/gakuwari2021/?icid=CRP_TOP_to_CRP_SPE_teacher_gakuwari2021
# 137 - /campaign_event/promotion/amazon_prime/?icid=CRP_TOP_to_CRP_CAM_promotion_amazon_prime
# 138 - https://service.smt.docomo.ne.jp/site/special/src/campaign_index.html?utm_source=corp_rec&utm_medium=free-display&utm_campaign=ddx_201912_set
# 139 - https://dpoint.jp/cp_3/d-wifi2_200817/index.html?utm_source=corp&utm_medium=free-display&utm_campaign=dpc_202008_free-dis-dwifi2-camp-09
# 140 - https://service.smt.docomo.ne.jp/keitai_payment/campaign/index.html
# 141 - /campaign_event/5g-welcome_wari/?icid=CRP_TOP_to_CRP_CAM_5g-welcome_wari
# 142 - https://dpoint.jp/cp_2/list_201201_1783/index.html?utm_source=corp_info&utm_medium=browserhome&utm_campaign=dpc_202012_1783&utm_content=pc_a
# 143 - /special_contents/teacher/gakuwari2021/?icid=CRP_TOP_to_CRP_SPE_teacher_gakuwari2021
# 144 - /campaign_event/promotion/amazon_prime/?icid=CRP_TOP_to_CRP_CAM_promotion_amazon_prime
# 145 - https://service.smt.docomo.ne.jp/site/special/src/campaign_index.html?utm_source=corp_rec&utm_medium=free-display&utm_campaign=ddx_201912_set
# 146 - https://dpoint.jp/cp_3/d-wifi2_200817/index.html?utm_source=corp&utm_medium=free-display&utm_campaign=dpc_202008_free-dis-dwifi2-camp-09
# 147 - https://service.smt.docomo.ne.jp/keitai_payment/campaign/index.html
# 148 - /campaign_event/5g-welcome_wari/?icid=CRP_TOP_to_CRP_CAM_5g-welcome_wari
# 149 - /campaign_event/?icid=CRP_TOP_to_CRP_CAM
# 150 - https://www.ntt.co.jp/topics/important/covid19.html
# 151 - /info/rss/
# 152 - /info/notice/page/201228_00.html
# 153 - /info/notice/page/201223_00_m.html
# 154 - /info/notice/page/201217_01_m.html
# 155 - https://www.nttdocomo.co.jp/info/notice/page/190725_01.html
# 156 - /info/notice/page/180725_00_m.html
# 157 - /info/notice/?icid=CRP_TOP_to_CRP_INFO_notice
# 158 - /info/rss/
# 159 - https://www.nttdocomo.co.jp/support/cs_case/index.html
# 160 - https://www.nttdocomo.co.jp/service/sugotoku/index.html
# 161 - https://www.nttdocomo.co.jp/charge/#sec_plan-5g
# 162 - /info/update/?icid=CRP_TOP_to_CRP_INFO_update
# 163 - /info/news_release/?icid=CRP_TOP_to_CRP_INFO_news_release
# 164 - /support/product_update/?icid=CRP_TOP_to_CRP_SUP_product_update
# 165 - /support/product_update/?icid=CRP_TOP_to_CRP_SUP_product_update
# 166 - /info/construction/?icid=CRP_TOP_to_CRP_INFO_construction
# 167 - /info/construction/?icid=CRP_TOP_to_CRP_INFO_construction
# 168 - /info/disaster/?icid=CRP_TOP_to_CRP_INFO_disaster#tab-01-p01
# 169 - /info/disaster/?icid=CRP_TOP_to_CRP_INFO_disaster#p01
# 170 - /corporate/about/?icid=CRP_TOP_to_CRP_CORP_about
# 171 - /corporate/about/?icid=CRP_TOP_to_CRP_CORP_about
# 172 - /corporate/csr/?icid=CRP_TOP_to_CRP_CORP_csr
# 173 - /corporate/csr/?icid=CRP_TOP_to_CRP_CORP_csr
# 174 - /support/cs.html?icid=CRP_TOP_to_CRP_SUP_cs
# 175 - /support/cs.html?icid=CRP_TOP_to_CRP_SUP_cs
# 176 - /corporate/ir/?icid=CRP_TOP_to_CRP_CORP_ir
# 177 - /corporate/ir/?icid=CRP_TOP_to_CRP_CORP_ir
# 178 - /corporate/recruit/?icid=CRP_TOP_to_CRP_CORP_recruit
# 179 - /corporate/recruit/?icid=CRP_TOP_to_CRP_CORP_recruit
# 180 - /corporate/ir/library/announcement/?icid=CRP_TOP_to_CRP_CORP_ir_library_announcement
# 181 - /corporate/ir/library/announcement/?icid=CRP_TOP_to_CRP_CORP_ir_library_announcement
# 182 - #
# 183 - /special_contents/teacher/gakuwari2021/?icid=CRP_TOP_cm_to_CRP_SPE_teacher_gakuwari2021
# 184 - #
# 185 - /support/promotion/migration/?icid=CRP_TOP_cm_to_CRP_SUP_promotion_migration
# 186 - #
# 187 - /special_contents/5g/?icid=CRP_TOP_cm_to_CRP_SPE_5g
# 188 - /special_contents/?icid=CRP_TOP_to_CRP_SPE
# 189 - https://www.facebook.com/docomo.official
# 190 - https://twitter.com/docomo
# 191 - /utility/personal_data/social_media/?icid=CRP_TOP_to_CRP_UTI_personal_data_social_media_line#line
# 192 - https://www.youtube.com/user/docomoOfficial
# 193 - https://www.instagram.com/docomo.official/
# 194 - /utility/personal_data/social_media/?icid=CRP_TOP_to_CRP_UTI_personal_data_social_media
# 195 - /special_contents/5g/?icid=CRP_TOP_to_CRP_SPE_5g
# 196 - /special_contents/beyond2020/tokyo2020/index4_2020.html?icid=CRP_TOP_to_CRP_SPE_beyond2020_tokyo2020_index4_2020
# 197 - /special_contents/disaster/?icid=CRP_TOP_to_CRP_SPE_disaster
# 198 - http://coda-cj.jp/enlightenment/manga.html
# 199 - http://www.npa.go.jp/bureau/safetylife/bohankyoshitsu/2nd/
# 200 - /hokkaido/?icid=CRP_TOP_to_hokkaido
# 201 - /tohoku/?icid=CRP_TOP_to_tohoku
# 202 - /kanto/?icid=CRP_TOP_to_kanto
# 203 - /tokai/?icid=CRP_TOP_to_tokai
# 204 - /hokuriku/?icid=CRP_TOP_to_hokuriku
# 205 - /kansai/?icid=CRP_TOP_to_kansai
# 206 - /chugoku/?icid=CRP_TOP_to_chugoku
# 207 - /shikoku/?icid=CRP_TOP_to_shikoku
# 208 - /kyushu/?icid=CRP_TOP_to_kyushu
# 209 - #
# 210 - /support/chat/
# 211 - #survey
# 212 - #
# 213 - #survey
# 214 - /utility/privacy/?icid=CRP_SURVEY_to_CRP_UTI_privacy
# 215 - /utility/privacy/?icid=CRP_SURVEY_end_to_CRP_UTI_privacy
# 216 - https://www.nttdocomo.co.jp/product/?icid=CRP_common_footer_to_CRP_PRD
# 217 - https://www.nttdocomo.co.jp/product/smart_phone_5g.html?icid=CRP_common_footer_to_CRP_PRD_smart_phone_5g
# 218 - https://www.nttdocomo.co.jp/product/smart_phone.html?icid=CRP_common_footer_to_CRP_PRD_smart_phone
# 219 - https://www.nttdocomo.co.jp/product/tablet.html?icid=CRP_common_footer_to_CRP_PRD_tablet
# 220 - https://www.nttdocomo.co.jp/product/feature_phone.html?icid=CRP_common_footer_to_CRP_PRD_feature_phone
# 221 - https://www.nttdocomo.co.jp/product/easy_phone.html?icid=CRP_common_footer_to_CRP_PRD_easy_phone
# 222 - https://www.nttdocomo.co.jp/product/kids_junior.html?icid=CRP_common_footer_to_CRP_PRD_kids_junior
# 223 - https://www.nttdocomo.co.jp/product/one_number.html?icid=CRP_common_footer_to_CRP_PRD_one_number
# 224 - https://www.nttdocomo.co.jp/product/data.html?icid=CRP_common_footer_to_CRP_PRD_data
# 225 - https://www.nttdocomo.co.jp/product/drivers_support.html?icid=CRP_common_footer_to_CRP_PRD_drivers_support
# 226 - https://www.nttdocomo.co.jp/product/docomo_select.html?icid=CRP_common_footer_to_CRP_PRD_docomo_select
# 227 - https://www.nttdocomo.co.jp/product/xr.html?icid=CRP_common_footer_to_CRP_PRD_xr
# 228 - https://www.nttdocomo.co.jp/charge/?icid=CRP_common_footer_to_CRP_CHA
# 229 - https://www.nttdocomo.co.jp/charge/5g-gigaho/?icid=CRP_common_footer_to_CRP_CHA_5g-gigaho
# 230 - https://www.nttdocomo.co.jp/charge/5g-gigalite/?icid=CRP_common_footer_to_CRP_CHA_5g-gigalite
# 231 - https://www.nttdocomo.co.jp/charge/gigaho-2/?icid=CRP_common_footer_to_CRP_CHA_gigaho-2
# 232 - https://www.nttdocomo.co.jp/charge/gigalite-2/?icid=CRP_common_footer_to_CRP_CHA_gigalite-2
# 233 - https://www.nttdocomo.co.jp/charge/discount.html?icid=CRP_common_footer_to_CRP_CHA_discount
# 234 - https://www.nttdocomo.co.jp/charge/simulation/?icid=CRP_common_footer_to_CRP_CHA_simulation
# 235 - https://www.nttdocomo.co.jp/service/?icid=CRP_common_footer_to_CRP_SER
# 236 - https://www.nttdocomo.co.jp/service/list.html?icid=CRP_common_footer_to_CRP_SER_list
# 237 - https://www.nttdocomo.co.jp/service/dmarket/?icid=CRP_common_footer_to_CRP_SER_dmarket
# 238 - https://www.nttdocomo.co.jp/service/wifi/?icid=CRP_common_footer_to_CRP_SER_wifi
# 239 - https://www.nttdocomo.co.jp/service/world/?icid=CRP_common_footer_to_CRP_SER_world
# 240 - https://www.nttdocomo.co.jp/area/?icid=CRP_common_footer_to_CRP_AREA
# 241 - https://www.nttdocomo.co.jp/area/service_area.html?icid=CRP_common_footer_to_CRP_AREA_service_area
# 242 - https://www.nttdocomo.co.jp/area/reception.html?icid=CRP_common_footer_to_CRP_AREA_reception
# 243 - https://www.nttdocomo.co.jp/area/effort.html?icid=CRP_common_footer_to_CRP_AREA_effort
# 244 - https://www.nttdocomo.co.jp/area/connect.html?icid=CRP_common_footer_to_CRP_AREA_connect
# 245 - https://www.nttdocomo.co.jp/area/technology.html?icid=CRP_common_footer_to_CRP_AREA_technology
# 246 - https://www.nttdocomo.co.jp/support/?icid=CRP_common_footer_to_CRP_SUP
# 247 - https://www.nttdocomo.co.jp/support/apple.html?icid=CRP_common_footer_to_CRP_SUP_apple
# 248 - https://www.nttdocomo.co.jp/support/product.html?icid=CRP_common_footer_to_CRP_SUP_product
# 249 - https://www.nttdocomo.co.jp/support/charge.html?icid=CRP_common_footer_to_CRP_SUP_charge
# 250 - https://www.nttdocomo.co.jp/support/service.html?icid=CRP_common_footer_to_CRP_SUP_service
# 251 - https://www.nttdocomo.co.jp/support/area.html?icid=CRP_common_footer_to_CRP_SUP_area
# 252 - https://www.nttdocomo.co.jp/support/hikari.html?icid=CRP_common_footer_to_CRP_SUP_hikari
# 253 - https://www.nttdocomo.co.jp/support/procedure.html?icid=CRP_common_footer_to_CRP_SUP_procedure
# 254 - https://www.nttdocomo.co.jp/support/inquiry.html?icid=CRP_common_footer_to_CRP_SUP_inquiry
# 255 - https://www.nttdocomo.co.jp/iphone/?icid=CRP_common_footer_to_CRP_IPH
# 256 - https://www.nttdocomo.co.jp/iphone/12-pro/?icid=CRP_common_footer_to_CRP_IPH_12-pro
# 257 - https://www.nttdocomo.co.jp/iphone/12/?icid=CRP_common_footer_to_CRP_IPH_12
# 258 - https://www.nttdocomo.co.jp/iphone/se_2nd/?icid=CRP_common_footer_to_CRP_IPH_se_2nd
# 259 - https://www.nttdocomo.co.jp/iphone/11-pro/?icid=CRP_common_footer_to_CRP_IPH_11-pro
# 260 - https://www.nttdocomo.co.jp/iphone/11/?icid=CRP_common_footer_to_CRP_IPH_11
# 261 - https://www.nttdocomo.co.jp/iphone/support/?icid=CRP_common_footer_to_CRP_IPH_support
# 262 - https://www.nttdocomo.co.jp/ipad/?icid=CRP_common_footer_to_CRP_IPA
# 263 - https://www.nttdocomo.co.jp/ipad/air-4th/?icid=CRP_common_footer_to_CRP_IPA_air-4th
# 264 - https://www.nttdocomo.co.jp/ipad/ipad-8th/?icid=CRP_common_footer_to_CRP_IPA_ipad-8th
# 265 - https://www.nttdocomo.co.jp/ipad/pro/?icid=CRP_common_footer_to_CRP_IPA_pro-12-9
# 266 - https://www.nttdocomo.co.jp/ipad/pro/?icid=CRP_common_footer_to_CRP_IPA_pro-11
# 267 - https://www.nttdocomo.co.jp/ipad/mini/?icid=CRP_common_footer_to_CRP_IPA_mini
# 268 - https://www.nttdocomo.co.jp/service/smart-life/?icid=CRP_common_footer_to_CRP_SER_smart-life
# 269 - https://www.nttdocomo.co.jp/service/smart-life/?icid=CRP_common_footer_to_CRP_SER_smart-life_entertainment&tgl_entertainment=1&tgl_life-support=0&tgl_finance=0&tgl_shopping=0&tgl_healthcare=0#entertainment
# 270 - https://www.nttdocomo.co.jp/service/smart-life/?icid=CRP_common_footer_to_CRP_SER_smart-life_life-support&tgl_entertainment=0&tgl_life-support=1&tgl_finance=0&tgl_shopping=0&tgl_healthcare=0#life-support
# 271 - https://www.nttdocomo.co.jp/service/smart-life/?icid=CRP_common_footer_to_CRP_SER_smart-life_finance&tgl_entertainment=0&tgl_life-support=0&tgl_finance=1&tgl_shopping=0&tgl_healthcare=0#finance
# 272 - https://www.nttdocomo.co.jp/service/smart-life/?icid=CRP_common_footer_to_CRP_SER_smart-life_shopping&tgl_entertainment=0&tgl_life-support=0&tgl_finance=0&tgl_shopping=1&tgl_healthcare=0#shopping
# 273 - https://www.nttdocomo.co.jp/service/smart-life/?icid=CRP_common_footer_to_CRP_SER_smart-life_healthcare&tgl_entertainment=0&tgl_life-support=0&tgl_finance=0&tgl_shopping=0&tgl_healthcare=1#healthcare
# 274 - https://www.nttdocomo.co.jp/hikari/?icid=CRP_common_footer_to_CRP_HIKARI
# 275 - https://www.nttdocomo.co.jp/hikari/charge/?icid=CRP_common_footer_to_CRP_HIKARI_charge
# 276 - https://www.nttdocomo.co.jp/hikari/beginner/?icid=CRP_common_footer_to_CRP_HIKARI_beginner
# 277 - https://www.nttdocomo.co.jp/hikari/tell_service/?icid=CRP_common_footer_to_CRP_HIKARI_tell_service
# 278 - https://www.nttdocomo.co.jp/hikari/eizo_service.html?icid=CRP_common_footer_to_CRP_HIKARI_eizo_service
# 279 - https://www.nttdocomo.co.jp/hikari/support/?icid=CRP_common_footer_to_CRP_HIKARI_support
# 280 - https://www.nttdocomo.co.jp/mydocomo/?icid=CRP_common_footer_to_CRP_MYD
# 281 - https://www.nttdocomo.co.jp/mydocomo/data/?icid=CRP_common_footer_to_CRP_MYD_data
# 282 - https://www.nttdocomo.co.jp/mydocomo/payment/?icid=CRP_common_footer_to_CRP_MYD_payment
# 283 - https://www.nttdocomo.co.jp/mydocomo/procedures/?icid=CRP_common_footer_to_CRP_MYD_procedures
# 284 - https://www.nttdocomo.co.jp/mydocomo/settings/?icid=CRP_common_footer_to_CRP_MYD_settings
# 285 - https://www.nttdocomo.co.jp/mydocomo/point/?icid=CRP_common_footer_to_CRP_MYD_point
# 286 - https://www.nttdocomo.co.jp/mydocomo/support/?icid=CRP_common_footer_to_CRP_MYD_support
# 287 - https://onlineshop.smt.docomo.ne.jp/index.html?xcid=OLS_TOP_from_CRP_common_footer
# 288 - https://www.nttdocomo.co.jp/campaign_event/?icid=CRP_common_footer_to_CRP_CAM
# 289 - https://www.nttdocomo.co.jp/utility/daccount/?icid=CRP_common_footer_to_CRP_UTI_daccount
# 290 - https://www.nttdocomo.co.jp/support/shop/?icid=CRP_common_footer_to_CRP_SUP_shop
# 291 - https://www.nttdocomo.co.jp/info/?icid=CRP_common_footer_to_CRP_INFO
# 292 - https://faq.nttdocomo.co.jp/faq/
# 293 - https://faq.nttdocomo.co.jp/faq/s/
# 294 - https://www.nttdocomo.co.jp/english/?icid=CRP_common_footer_to_CRP_EN
# 295 - https://www.nttdocomo.co.jp/utility/personal_data/?icid=CRP_common_footer_to_CRP_UTI_personal_data
# 296 - https://www.nttdocomo.co.jp/utility/privacy/?icid=CRP_common_footer_to_CRP_UTI_privacy
# 297 - https://www.nttdocomo.co.jp/utility/term/?icid=CRP_common_footer_to_CRP_UTI_term
# 298 - https://www.nttdocomo.co.jp/support/feedback.html?icid=CRP_common_footer_to_CRP_SUP_feedback
# 299 - https://www.nttdocomo.co.jp/mydocomo/maint/?icid=CRP_common_footer_to_CRP_MYD_maint
# 300 - https://www.nttdocomo.co.jp/sitemap/?icid=CRP_common_footer_to_CRP_sitemap
# 301 - https://faq.nttdocomo.co.jp/faq/s/
# 302 - /support/inquiry/?icid=CRP_drawer_to_CRP_SUP_inquiry
# 303 - /info/?icid=CRP_drawer_to_CRP_INF
# 304 - /corporate/?icid=CRP_drawer_to_CRP_CORP
# 305 - /biz/?icid=CRP_common_header_to_CRP_BIZ_TOP
