# %%
import nest_asyncio

nest_asyncio.apply()
print("Event loop ready.")
# Out:
# Event loop ready.

# %%
from rasa.cli.scaffold import create_initial_project
import os

project = "test-project"
create_initial_project(project)

# move into project directory and show files
os.chdir(project)
print(os.listdir("."))
# Out:
# ['data', 'test-project', 'config.yml', 'actions.py', '__init__.py', 'tests', '__pycache__', 'credentials.yml', 'endpoints.yml', 'domain.yml']

# %%
# config = "config.yml"
# training_files = "data/"
# domain = "domain.yml"
# output = "models/"

# %%
config = "/home/iftekhar/myworkplace/exp_amieCore/amieCore/amie_core/core/rasa/config.yml"
training_files = "/home/iftekhar/myworkplace/exp_amieCore/amieCore/amie_core/core/rasa/data/"
domain = "/home/iftekhar/myworkplace/exp_amieCore/amieCore/amie_core/core/rasa/domain/domain_ja.yml"
output = "/home/iftekhar/myworkplace/Resources/rasa_model/"
print(config, training_files, domain, output)
# Out:
# /home/iftekhar/myworkplace/exp_amieCore/amieCore/amie_core/core/rasa/config.yml /home/iftekhar/myworkplace/exp_amieCore/amieCore/amie_core/core/rasa/data/ /home/iftekhar/myworkplace/exp_amieCore/amieCore/amie_core/core/rasa/domain/domain_ja.yml /home/iftekhar/myworkplace/Resources/rasa_model/

# %%
import rasa

model_path = rasa.train(domain, config, [training_files], output)
print(model_path)
# Out:
# /home/iftekhar/myworkplace/environments/rasa_test_jupyter/lib/python3.6/site-packages/rasa/core/domain.py:133: FutureWarning: Your domain file contains the key: 'templates'. This has been deprecated and renamed to 'responses'. The 'templates' key will no longer work in future versions of Rasa. Please replace 'templates' with 'responses'
#   return cls.from_dict(data)
# /home/iftekhar/myworkplace/environments/rasa_test_jupyter/lib/python3.6/site-packages/rasa/core/domain.py:151: FutureWarning: No tracker session configuration was found in the loaded domain. Domains without a session config will automatically receive a session expiration time of 60 minutes in Rasa version 2.0 if not configured otherwise.
#   session_config = cls._get_session_config(data.get(SESSION_CONFIG_KEY, {}))
# ...

# %%
from rasa.jupyter import chat
chat(model_path)
